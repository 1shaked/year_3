# %%
import sqlite3
from pathlib import Path
DB_PATH = "questions.db"

# Initialize the SQLite database
def init_db() -> None:
    """
    Initialize the SQLite database with questions, options, and answers tables.
    """
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    # Create questions table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS questions (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            question TEXT NOT NULL
        )
    ''')
    # Create options table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS options (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            question_id INTEGER NOT NULL,
            option_text TEXT NOT NULL,
            FOREIGN KEY(question_id) REFERENCES questions(id)
        )
    ''')
    # Create answers table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS answers (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            question_id INTEGER NOT NULL,
            option_id INTEGER NOT NULL,
            FOREIGN KEY(question_id) REFERENCES questions(id),
            FOREIGN KEY(option_id) REFERENCES options(id)
        )
    ''')
    conn.commit()
    conn.close()

# init_db()

# %%
# # insert the questions and options to the database, the answer is always the first option
# questions_pool = [
#     {
#         "question": "What are the three components of the Opportunity Assessment Framework (DVF)?",
#         "options": [
#             "Desirability, Viability, Feasibility",
#             "Design, Validation, Functionality",
#             "Demand, Volume, Forecast",
#             "Data, Visualization, Flow"
#         ]
#     },
#     {
#         "question": "What is a key advantage of using a Data Warehouse?",
#         "options": [
#             "Centralized, clean, and structured data for analysis",
#             "Faster internet browsing",
#             "Improved image resolution",
#             "Automatic password protection"
#         ]
#     },
#     {
#         "question": "What does ETL stand for?",
#         "options": [
#             "Extract, Transform, Load",
#             "Evaluate, Test, Launch",
#             "Encrypt, Transfer, Link",
#             "Execute, Transmit, Loop"
#         ]
#     },
#     {
#         "question": "What type of schema has a central fact table connected to multiple dimension tables?",
#         "options": [
#             "Star Schema",
#             "Galaxy Schema",
#             "Snowflake Schema",
#             "Flat Schema"
#         ]
#     },
#     {
#         "question": "Which of the following is a fact table example in retail?",
#         "options": [
#             "Sales",
#             "Product",
#             "Customer",
#             "Store"
#         ]
#     },
#     {
#         "question": "What is data granularity?",
#         "options": [
#             "The level of detail stored in the data warehouse",
#             "The speed of the data connection",
#             "The visual appearance of dashboards",
#             "The format of exported charts"
#         ]
#     },
#     {
#         "question": "What is the purpose of dimensional modeling?",
#         "options": [
#             "To simplify complex data relationships and improve query performance",
#             "To encrypt business data",
#             "To design mobile applications",
#             "To format PDFs for printing"
#         ]
#     },
#     {
#         "question": "Which of the following is NOT typically a component of a Data Warehouse?",
#         "options": [
#             "Firewall Manager",
#             "Data Sources",
#             "ETL Process",
#             "Business Intelligence Tools"
#         ]
#     },
#     {
#         "question": "Which of the following describes a dimension table?",
#         "options": [
#             "Table that provides context and descriptive attributes for facts",
#             "Stores large volumes of sensor data",
#             "Contains encryption keys for ETL",
#             "Summarizes only financial information"
#         ]
#     },
#     {
#         "question": "Which tool is commonly used for business intelligence and data visualization?",
#         "options": [
#             "Tableau",
#             "AutoCAD",
#             "Python Flask",
#             "Notepad++"
#         ]
#     },
#     {
#         "question": "What is OLAP used for?",
#         "options": [
#             "Multidimensional analysis and fast data retrieval",
#             "Sending emails in bulk",
#             "Designing webpages",
#             "Developing mobile games"
#         ]
#     },
#     {
#         "question": "Which schema is more normalized than a Star Schema?",
#         "options": [
#             "Snowflake Schema",
#             "Flat Schema",
#             "Merged Schema",
#             "Circular Schema"
#         ]
#     },
#     {
#         "question": "What is an example of unstructured data?",
#         "options": [
#             "Customer reviews",
#             "Sales transaction records",
#             "Store inventory table",
#             "Employee payroll file"
#         ]
#     },
#     {
#         "question": "Why is historical data important in data warehouses?",
#         "options": [
#             "It supports trend analysis and long-term decisions",
#             "It reduces storage cost",
#             "It eliminates the need for ETL",
#             "It speeds up web servers"
#         ]
#     },
#     {
#         "question": "Which of the following is a challenge in ETL processes?",
#         "options": [
#             "Ensuring data security and handling volume",
#             "Designing mobile-friendly layouts",
#             "Choosing font colors",
#             "Avoiding email spam"
#         ]
#     },
#     {
#         "question": "Which of the following is a benefit of using OLAP cubes?",
#         "options": [
#             "Facilitates fast multidimensional data analysis",
#             "Compresses video files",
#             "Enhances image rendering",
#             "Blocks malicious traffic"
#         ]
#     },
#     {
#         "question": "What is a key purpose of a Business Intelligence (BI) Tool?",
#         "options": [
#             "To help users visualize and analyze data for decisions",
#             "To manage social media accounts",
#             "To edit PDF files",
#             "To store customer passwords"
#         ]
#     },
#     {
#         "question": "What does 'data profiling' in ETL refer to?",
#         "options": [
#             "Analyzing source data to identify quality issues",
#             "Creating user interface mockups",
#             "Summarizing historical video data",
#             "Managing payroll schedules"
#         ]
#     },
#     {
#         "question": "What kind of schema allows many fact tables to share dimension tables?",
#         "options": [
#             "Galaxy Schema",
#             "Flat Schema",
#             "Linear Schema",
#             "Columnar Schema"
#         ]
#     },
#     {
#         "question": "What does 'slice' mean in the context of OLAP cubes?",
#         "options": [
#             "Filtering the cube by one dimension",
#             "Adding new schema models",
#             "Resetting cube metadata",
#             "Extracting logs from sensors"
#         ]
#     }
# ]

# def insert_questions(questions: list) -> None:
#     """
#     Insert questions and their options into the database.
#     """
#     conn = sqlite3.connect(DB_PATH)
#     cursor = conn.cursor()
    
#     for question_data in questions:
#         cursor.execute('INSERT INTO questions (question) VALUES (?)', (question_data["question"],))
#         question_id = cursor.lastrowid
#         option_id_answer = None
#         for option in question_data["options"]:
#             cursor.execute('INSERT INTO options (question_id, option_text) VALUES (?, ?)', (question_id, option))
#             if option_id_answer is None:
#                 # select the last inserted question_id
#                 option_id_answer = cursor.lastrowid
#                 print(f"Question ID is {option_id_answer}")

#         # Insert the answer as the first option
#         cursor.execute('INSERT INTO answers (question_id, option_id) VALUES (?, ?)', (question_id, option_id_answer))
    
#     conn.commit()
#     conn.close()

# %%
# insert_questions(questions_pool)

# %%
# # reset all the data in the database
# def reset_db() -> None:
#     """
#     Reset the database by dropping all tables and reinitializing.
#     """
#     conn = sqlite3.connect(DB_PATH)
#     cursor = conn.cursor()
    
#     cursor.execute('DROP TABLE IF EXISTS answers')
#     cursor.execute('DROP TABLE IF EXISTS options')
#     cursor.execute('DROP TABLE IF EXISTS questions')
    
#     init_db()
    
#     conn.close()

# # reset_db()

# %%
# # Generate 25 quiz questions based on the key topics identified above

# questions_lecture3 = [
#     {
#         "question": "What is the main goal of user research?",
#         "options": [
#             "Understand user needs, behavior, and context",
#             "Design the database schema",
#             "Build a website",
#             "Write SQL queries"
#         ]
#     },
#     {
#         "question": "What is a primary user?",
#         "options": [
#             "A user for whom the system is designed",
#             "A user who supports other users",
#             "A developer of the system",
#             "A tester of the system"
#         ]
#     },
#     {
#         "question": "What is a secondary user?",
#         "options": [
#             "A user indirectly affected by the system",
#             "A customer service representative",
#             "An administrator of the system",
#             "A persona used for testing"
#         ]
#     },
#     {
#         "question": "Which is a qualitative research method?",
#         "options": [
#             "Interview",
#             "Survey",
#             "Web analytics",
#             "Usage logs"
#         ]
#     },
#     {
#         "question": "What does UX stand for?",
#         "options": [
#             "User Experience",
#             "Ultimate Execution",
#             "Unified Exchange",
#             "User Extension"
#         ]
#     },
#     {
#         "question": "Which method involves direct observation of user behavior?",
#         "options": [
#             "Naturalistic observation",
#             "Questionnaire",
#             "Focus group",
#             "A/B testing"
#         ]
#     },
#     {
#         "question": "What is a persona in user research?",
#         "options": [
#             "A fictional character representing a user group",
#             "A software tool",
#             "A server name",
#             "A marketing tactic"
#         ]
#     },
#     {
#         "question": "Which user research method helps in collecting multiple viewpoints?",
#         "options": [
#             "Focus groups",
#             "ETL process",
#             "Interviews",
#             "Prototyping"
#         ]
#     },
#     {
#         "question": "Which of the following is NOT a data collection method?",
#         "options": [
#             "Coding sprints",
#             "Interviews",
#             "Surveys",
#             "Observations"
#         ]
#     },
#     {
#         "question": "What kind of data is collected through usage logs?",
#         "options": [
#             "Quantitative",
#             "Qualitative",
#             "Narrative",
#             "Audio recordings"
#         ]
#     },
#     {
#         "question": "What is the purpose of a micro-scenario?",
#         "options": [
#             "Describe a specific short interaction",
#             "Outline marketing strategy",
#             "Measure memory retention",
#             "Calculate ROI"
#         ]
#     },
#     {
#         "question": "What is one disadvantage of focus groups?",
#         "options": [
#             "Groupthink or dominant participants",
#             "Expensive software tools",
#             "Too little user feedback",
#             "Requires coding skills"
#         ]
#     },
#     {
#         "question": "Why is user segmentation important?",
#         "options": [
#             "Different users have different needs and behaviors",
#             "To save storage space",
#             "To encrypt data",
#             "To test code efficiently"
#         ]
#     },
#     {
#         "question": "What is a macro-scenario used for?",
#         "options": [
#             "Understanding long-term user behavior across contexts",
#             "Coding algorithm efficiency",
#             "UI font comparison",
#             "Database joins"
#         ]
#     },
#     {
#         "question": "Which attribute affects UI design for older adults?",
#         "options": [
#             "Age",
#             "Favorite color",
#             "Phone brand",
#             "Eye color"
#         ]
#     },
#     {
#         "question": "Which of the following is part of a persona?",
#         "options": [
#             "Pain points and usage goals",
#             "Phone number",
#             "Salary slip",
#             "MAC address"
#         ]
#     },
#     {
#         "question": "What is the aim of task analysis?",
#         "options": [
#             "Understanding how users perform tasks to reach goals",
#             "Creating animation effects",
#             "Compiling code quickly",
#             "Securing user data"
#         ]
#     },
#     {
#         "question": "What does the 'context' in user-centered design refer to?",
#         "options": [
#             "User's environment and situation of use",
#             "Programming language",
#             "Website layout",
#             "File format"
#         ]
#     },
#     {
#         "question": "Which tool is used to record screen and input devices?",
#         "options": [
#             "Observation suite",
#             "Firewall",
#             "Cookie manager",
#             "Voice assistant"
#         ]
#     },
#     {
#         "question": "What does segmentation in user profiling enable?",
#         "options": [
#             "Grouping similar users for better design decisions",
#             "Encrypting profiles",
#             "Merging databases",
#             "Creating animation styles"
#         ]
#     },
#     {
#         "question": "What is the purpose of interviews in user research?",
#         "options": [
#             "To explore user needs and motivations",
#             "To test WiFi speed",
#             "To encrypt cookies",
#             "To install software"
#         ]
#     },
#     {
#         "question": "What is meant by user journey mapping?",
#         "options": [
#             "Visualizing the entire interaction process of a user with a system",
#             "Plotting customer addresses",
#             "Mapping mouse movement on screen",
#             "Saving user login details"
#         ]
#     },
#     {
#         "question": "Which of the following is a major challenge of observation?",
#         "options": [
#             "It is time-consuming and data-heavy",
#             "Requires SQL knowledge",
#             "Is only suitable for video games",
#             "Produces fake user data"
#         ]
#     },
#     {
#         "question": "What can cause errors in UI design?",
#         "options": [
#             "Mismatch between user ability and system demands",
#             "Low resolution images",
#             "Outdated operating systems",
#             "Insufficient RAM"
#         ]
#     },
#     {
#         "question": "What is customization in user interfaces?",
#         "options": [
#             "Allowing users to change elements to suit their needs",
#             "Blocking users from logging in",
#             "Color coding folders",
#             "Downloading fonts"
#         ]
#     }
# ]
# insert_questions(questions_lecture3)

# %%
# # Create 25 content-specific questions for Lecture 4: Usability & User-Centered Design

# questions_lecture4 = [
#     {
#         "question": "What does ISO 9241-11 define?",
#         "options": [
#             "Usability in terms of effectiveness, efficiency, and satisfaction",
#             "Software development life cycle",
#             "Data warehouse architecture",
#             "User testing procedures"
#         ]
#     },
#     {
#         "question": "Which of the following is NOT one of Nielsen's five usability dimensions?",
#         "options": [
#             "Portability",
#             "Efficiency",
#             "Memorability",
#             "Satisfaction"
#         ]
#     },
#     {
#         "question": "What is 'learnability' in usability?",
#         "options": [
#             "How easily users can learn to use the interface",
#             "The software’s ability to adapt to networks",
#             "The system’s compatibility with cloud services",
#             "The user’s memory retention rate"
#         ]
#     },
#     {
#         "question": "Which KPI is commonly used to measure user satisfaction?",
#         "options": [
#             "Net Promoter Score (NPS)",
#             "ETL Success Rate",
#             "Data Redundancy Index",
#             "Download Speed"
#         ]
#     },
#     {
#         "question": "What is a 'slip' in terms of usability errors?",
#         "options": [
#             "An unintentional action execution error",
#             "A deliberate misuse of the system",
#             "A missing documentation",
#             "A network failure"
#         ]
#     },
#     {
#         "question": "What is the goal of user-centered design?",
#         "options": [
#             "Designing with the user's needs, limitations, and context in mind",
#             "Focusing on technical system performance",
#             "Maximizing profit through advertisements",
#             "Ensuring government compliance"
#         ]
#     },
#     {
#         "question": "Which heuristic suggests using familiar language and concepts?",
#         "options": [
#             "Match between system and the real world",
#             "Aesthetic and minimalist design",
#             "Flexibility and efficiency of use",
#             "Help users recognize, diagnose, and recover from errors"
#         ]
#     },
#     {
#         "question": "What should error messages do according to usability guidelines?",
#         "options": [
#             "Help users understand and recover from the error",
#             "Only show technical codes",
#             "Be hidden to avoid confusing users",
#             "Immediately log out the user"
#         ]
#     },
#     {
#         "question": "What is the V in the VIMM model?",
#         "options": [
#             "Visual load",
#             "Verification level",
#             "Virtual input",
#             "Video latency"
#         ]
#     },
#     {
#         "question": "Which dimension of usability is MOST related to how quickly tasks can be completed?",
#         "options": [
#             "Efficiency",
#             "Satisfaction",
#             "Memorability",
#             "Error rate"
#         ]
#     },
#     {
#         "question": "Which of the following reduces intellectual load?",
#         "options": [
#             "Clear and simple instructions",
#             "Animated GIFs",
#             "Background music",
#             "Drag-and-drop interaction"
#         ]
#     },
#     {
#         "question": "Which heuristic recommends having an 'undo' button?",
#         "options": [
#             "User control and freedom",
#             "Help and documentation",
#             "Consistency and standards",
#             "Recognition rather than recall"
#         ]
#     },
#     {
#         "question": "What is the main purpose of Nielsen's heuristics?",
#         "options": [
#             "Evaluate the usability of interfaces",
#             "Track online user behavior",
#             "Monitor network latency",
#             "Define marketing personas"
#         ]
#     },
#     {
#         "question": "What does a high error rate indicate in usability testing?",
#         "options": [
#             "Users often make mistakes or struggle with tasks",
#             "The interface loads too quickly",
#             "Data cannot be exported",
#             "The UI is fully responsive"
#         ]
#     },
#     {
#         "question": "How does 'memorability' affect user experience?",
#         "options": [
#             "It shows how easily users can return to the system after a break",
#             "It measures server downtime",
#             "It tracks advertisement performance",
#             "It optimizes code for performance"
#         ]
#     },
#     {
#         "question": "What is a good method to reduce memory load in UI design?",
#         "options": [
#             "Use autocomplete and visual cues",
#             "Remove all labels",
#             "Require password input each time",
#             "Add detailed popups"
#         ]
#     },
#     {
#         "question": "What is the benefit of applying VIMM principles?",
#         "options": [
#             "To reduce cognitive burden on users",
#             "To enhance screen contrast",
#             "To replace analytics dashboards",
#             "To improve backend security"
#         ]
#     },
#     {
#         "question": "Which heuristic deals with minimizing irrelevant information?",
#         "options": [
#             "Aesthetic and minimalist design",
#             "Recognition rather than recall",
#             "Error prevention",
#             "Help and documentation"
#         ]
#     },
#     {
#         "question": "What is the purpose of feedback in UI design?",
#         "options": [
#             "Inform users about system status and actions",
#             "Close the application automatically",
#             "Increase memory usage",
#             "Encrypt user preferences"
#         ]
#     },
#     {
#         "question": "Which usability KPI focuses on the number of attempts users make to complete tasks?",
#         "options": [
#             "Error rate",
#             "NPS",
#             "Bandwidth",
#             "Click-through rate"
#         ]
#     },
#     {
#         "question": "What does motor load in the VIMM model refer to?",
#         "options": [
#             "Physical effort needed to interact with a system",
#             "Memory strain",
#             "CPU processing power",
#             "Network latency"
#         ]
#     },
#     {
#         "question": "Which principle helps users recover from accidental actions?",
#         "options": [
#             "Undo and cancel options",
#             "Color contrast tools",
#             "Video tutorials",
#             "Authentication logs"
#         ]
#     },
#     {
#         "question": "How does 'help and documentation' support usability?",
#         "options": [
#             "It assists users when they are stuck or unsure what to do",
#             "It reduces app download size",
#             "It stores user data logs",
#             "It increases video buffering speed"
#         ]
#     },
#     {
#         "question": "Which of the following is an intellectual load reduction strategy?",
#         "options": [
#             "Simplify instructions and use tooltips",
#             "Add decorative elements",
#             "Use abstract metaphors",
#             "Display raw JSON data"
#         ]
#     },
#     {
#         "question": "Which heuristic promotes shortcut use for experienced users?",
#         "options": [
#             "Flexibility and efficiency of use",
#             "Error prevention",
#             "Help users recover from errors",
#             "Aesthetic and minimalist design"
#         ]
#     }
# ]

# insert_questions(questions_lecture4)

# %%
# # Create 25 content-specific questions for Lecture 5: Data Visualization Design

# questions_lecture5 = [
#     {
#         "question": "Which of the following is NOT one of Nielsen’s 10 heuristics?",
#         "options": [
#             "Maximize graphical resolution",
#             "Visibility of system status",
#             "Help and documentation",
#             "Error prevention"
#         ]
#     },
#     {
#         "question": "What does Fitts' Law help predict?",
#         "options": [
#             "Time to reach a UI target based on size and distance",
#             "Internet download speeds",
#             "User memory load",
#             "Error rate in user interfaces"
#         ]
#     },
#     {
#         "question": "Which type of dashboard is designed for high-level KPIs and quick summaries?",
#         "options": [
#             "Executive dashboard",
#             "Operational dashboard",
#             "Analytical dashboard",
#             "Tactical dashboard"
#         ]
#     },
#     {
#         "question": "Which of the following principles is related to displaying only useful ink?",
#         "options": [
#             "Data-ink ratio",
#             "Aesthetic consistency",
#             "Visual realism",
#             "Feedback control"
#         ]
#     },
#     {
#         "question": "What is 'redundancy gain'?",
#         "options": [
#             "Using multiple sensory channels to convey the same message",
#             "Storing backup data across servers",
#             "Showing multiple dashboards on one screen",
#             "Copying charts between reports"
#         ]
#     },
#     {
#         "question": "Which type of chart is best for showing parts of a whole?",
#         "options": [
#             "Pie chart",
#             "Line chart",
#             "Radar chart",
#             "Histogram"
#         ]
#     },
#     {
#         "question": "What is the 'primary visual field'?",
#         "options": [
#             "Area most easily seen by users without head movement",
#             "Main text area of a document",
#             "Brightest portion of a dashboard",
#             "Upper-right corner of the interface"
#         ]
#     },
#     {
#         "question": "Which principle emphasizes placing related information close together?",
#         "options": [
#             "Proximity compatibility",
#             "Redundancy gain",
#             "Minimize access cost",
#             "Mental model alignment"
#         ]
#     },
#     {
#         "question": "Which visual principle suggests matching display format to user expectations?",
#         "options": [
#             "Pictorial realism",
#             "Color harmony",
#             "Visual dominance",
#             "Perspective simulation"
#         ]
#     },
#     {
#         "question": "Which of the following is a dynamic display?",
#         "options": [
#             "Real-time stock ticker",
#             "Printed temperature graph",
#             "Bar chart in a textbook",
#             "Screenshot of an app"
#         ]
#     },
#     {
#         "question": "Which scale type has no absolute zero and equal intervals?",
#         "options": [
#             "Interval scale",
#             "Nominal scale",
#             "Ratio scale",
#             "Ordinal scale"
#         ]
#     },
#     {
#         "question": "What does Fitts’ Law imply about target size in UI design?",
#         "options": [
#             "Larger targets are faster to reach",
#             "Larger targets increase memory load",
#             "Smaller targets improve aesthetics",
#             "Target size is irrelevant"
#         ]
#     },
#     {
#         "question": "Which dashboard type is used for long-term strategic decisions?",
#         "options": [
#             "Analytical dashboard",
#             "Operational dashboard",
#             "Tactical dashboard",
#             "Short-term dashboard"
#         ]
#     },
#     {
#         "question": "Which is NOT a visual clarity technique?",
#         "options": [
#             "Adding multiple color gradients",
#             "High contrast between foreground and background",
#             "Using contours to separate areas",
#             "Color coding important elements"
#         ]
#     },
#     {
#         "question": "Which principle aims to reduce the number of steps to get data?",
#         "options": [
#             "Minimize access cost",
#             "Maximize refresh rate",
#             "Increase data volume",
#             "Lower redundancy"
#         ]
#     },
#     {
#         "question": "Which of these is an example of a control requiring continuous input?",
#         "options": [
#             "Volume slider",
#             "Light switch",
#             "Radio button",
#             "Checkbox"
#         ]
#     },
#     {
#         "question": "What is the benefit of consistent visual encoding?",
#         "options": [
#             "Users can interpret repeated symbols quickly",
#             "It improves CPU performance",
#             "It increases visual clutter",
#             "It lowers system load"
#         ]
#     },
#     {
#         "question": "What type of chart is best for tracking trends over time?",
#         "options": [
#             "Line chart",
#             "Pie chart",
#             "Radar chart",
#             "Bubble chart"
#         ]
#     },
#     {
#         "question": "Which measurement scale is used for categories without order?",
#         "options": [
#             "Nominal",
#             "Ordinal",
#             "Interval",
#             "Ratio"
#         ]
#     },
#     {
#         "question": "What does the 'data-to-ink' ratio encourage designers to do?",
#         "options": [
#             "Remove unnecessary visual elements",
#             "Add as many colors as possible",
#             "Use artistic icons",
#             "Blend multiple charts together"
#         ]
#     },
#     {
#         "question": "Which factor influences display layout based on frequency of use?",
#         "options": [
#             "Place frequently used elements in easier-to-reach areas",
#             "Use same-sized elements for balance",
#             "Randomize placement for user stimulation",
#             "Make less-used features brighter"
#         ]
#     },
#     {
#         "question": "What is the key idea of 'mental model alignment'?",
#         "options": [
#             "System behavior should match user expectations",
#             "Visual elements must be 3D",
#             "Icons should be randomized",
#             "Typography must be uniform"
#         ]
#     },
#     {
#         "question": "Which characteristic distinguishes analytical dashboards?",
#         "options": [
#             "They support complex and detailed data exploration",
#             "They use animated icons",
#             "They require touch-only interfaces",
#             "They include only real-time alerts"
#         ]
#     },
#     {
#         "question": "What is the goal of visual discriminability?",
#         "options": [
#             "Make elements distinct and recognizable",
#             "Blend elements to minimize distraction",
#             "Repeat visuals to enhance familiarity",
#             "Display all elements in grayscale"
#         ]
#     },
#     {
#         "question": "Which input device is typically used for discrete selection?",
#         "options": [
#             "Checkbox",
#             "Joystick",
#             "Steering wheel",
#             "Mouse movement"
#         ]
#     }
# ]


# insert_questions(questions_lecture5)

# %%
# # Create 30 content-specific multiple-choice questions for Lectures 6 + 7

# questions_lectures_6_7 = [
#     {
#         "question": "What does Fitts' Law predict?",
#         "options": [
#             "Time required to move to a target area",
#             "User memory retention",
#             "Page loading time",
#             "Data processing speed"
#         ]
#     },
#     {
#         "question": "Which type of dashboard is primarily used for real-time data monitoring?",
#         "options": [
#             "Operational dashboard",
#             "Analytical dashboard",
#             "Strategic dashboard",
#             "Exploratory dashboard"
#         ]
#     },
#     {
#         "question": "What is a mental model?",
#         "options": [
#             "User's internal understanding of how a system works",
#             "A wireframe for UI",
#             "A visual graph",
#             "A marketing strategy"
#         ]
#     },
#     {
#         "question": "Which process is most related to how users interpret interfaces?",
#         "options": [
#             "Cognition",
#             "Rendering",
#             "Encryption",
#             "Data mining"
#         ]
#     },
#     {
#         "question": "What does the formula MT = a + b log₂(2A/W) describe?",
#         "options": [
#             "Fitts' Law",
#             "Hick's Law",
#             "Shannon's Theorem",
#             "Moore's Law"
#         ]
#     },
#     {
#         "question": "Which learning type is based on associations between stimuli?",
#         "options": [
#             "Classical conditioning",
#             "Cognitive learning",
#             "Procedural learning",
#             "Operant conditioning"
#         ]
#     },
#     {
#         "question": "What does operant conditioning involve?",
#         "options": [
#             "Reinforcement and punishment",
#             "Repetition of visual patterns",
#             "Retinal stimulation",
#             "Icon grouping"
#         ]
#     },
#     {
#         "question": "What is an example of gamification?",
#         "options": [
#             "Reward points in a fitness app",
#             "Changing font styles",
#             "Coloring charts",
#             "Compressing UI files"
#         ]
#     },
#     {
#         "question": "What kind of memory lasts only a few seconds?",
#         "options": [
#             "Sensory memory",
#             "Working memory",
#             "Long-term memory",
#             "Declarative memory"
#         ]
#     },
#     {
#         "question": "What is bottom-up attention driven by?",
#         "options": [
#             "Stimuli in the environment",
#             "User intention",
#             "System logs",
#             "Past experience"
#         ]
#     },
#     {
#         "question": "Which type of attention is controlled by user goals and expectations?",
#         "options": [
#             "Top-down attention",
#             "Bottom-up attention",
#             "Reflexive attention",
#             "Global attention"
#         ]
#     },
#     {
#         "question": "What is the Stroop Effect an example of?",
#         "options": [
#             "Cognitive interference",
#             "Visual clarity",
#             "Motor skills",
#             "Color harmony"
#         ]
#     },
#     {
#         "question": "Which theory discusses parallel vs serial visual search?",
#         "options": [
#             "Treisman and Gelade's theory",
#             "Hick's Law",
#             "Color theory",
#             "Fitts' Law"
#         ]
#     },
#     {
#         "question": "Which type of learning does Skinner's work relate to?",
#         "options": [
#             "Operant conditioning",
#             "Observational learning",
#             "Sensory learning",
#             "Conceptual learning"
#         ]
#     },
#     {
#         "question": "Which display principle helps reduce memory load?",
#         "options": [
#             "Use of icons and spatial layout",
#             "Random placement of menus",
#             "Minimized screen resolution",
#             "Animated transitions"
#         ]
#     },
#     {
#         "question": "Which of these is considered a reward mechanism in gamification?",
#         "options": [
#             "Progress bars",
#             "Dropdown menus",
#             "Pop-up blockers",
#             "Search filters"
#         ]
#     },
#     {
#         "question": "What does 'visual hierarchy' refer to?",
#         "options": [
#             "Ordering elements to guide attention",
#             "Positioning layers in code",
#             "Enabling scrolling",
#             "Setting up database tables"
#         ]
#     },
#     {
#         "question": "Which is an example of classic aesthetics?",
#         "options": [
#             "Symmetry and balance",
#             "Neon animation",
#             "3D rotation",
#             "Random font changes"
#         ]
#     },
#     {
#         "question": "Which memory type allows manipulation of information?",
#         "options": [
#             "Working memory",
#             "Echoic memory",
#             "Episodic memory",
#             "Procedural memory"
#         ]
#     },
#     {
#         "question": "What is the goal of screen alignment rules?",
#         "options": [
#             "Improve readability and organization",
#             "Reduce backend calls",
#             "Increase ad engagement",
#             "Optimize image resolution"
#         ]
#     },
#     {
#         "question": "Which display layout supports ease of navigation?",
#         "options": [
#             "Grid alignment",
#             "Scatter plot",
#             "Circular symmetry",
#             "Unstructured layout"
#         ]
#     },
#     {
#         "question": "Which of the following can influence attention in UI?",
#         "options": [
#             "Color, motion, and size",
#             "Code comments",
#             "Debug logs",
#             "Database indexes"
#         ]
#     },
#     {
#         "question": "What does model-based reinforcement learning involve?",
#         "options": [
#             "Planning based on known outcomes",
#             "Random exploration",
#             "Memory-only decision making",
#             "Visual-only behavior"
#         ]
#     },
#     {
#         "question": "Which type of dashboard is most suited for strategic decision-making?",
#         "options": [
#             "Analytical dashboard",
#             "Operational dashboard",
#             "Tactical dashboard",
#             "Design dashboard"
#         ]
#     },
#     {
#         "question": "Which attention type responds rapidly to external stimuli?",
#         "options": [
#             "Bottom-up",
#             "Top-down",
#             "Directed",
#             "Associative"
#         ]
#     },
#     {
#         "question": "What are Treisman and Gelade known for in visual theory?",
#         "options": [
#             "Feature Integration Theory",
#             "Encoding feedback loops",
#             "Dashboard development",
#             "Decision trees"
#         ]
#     },
#     {
#         "question": "What is a practical implication of Fitts’ Law in UI design?",
#         "options": [
#             "Larger and closer buttons are easier to click",
#             "Use long drop-downs",
#             "Use abstract icons",
#             "Group all items in top-left"
#         ]
#     },
#     {
#         "question": "Which type of attention is goal-driven and voluntary?",
#         "options": [
#             "Top-down",
#             "Bottom-up",
#             "Reflexive",
#             "Unconscious"
#         ]
#     },
#     {
#         "question": "What concept suggests matching design with user expectations?",
#         "options": [
#             "Mental model alignment",
#             "Visual affordance",
#             "Heuristic anchoring",
#             "Style sheet conversion"
#         ]
#     },
#     {
#         "question": "What role do feedback and reinforcement play in user behavior?",
#         "options": [
#             "Shape repeated behavior",
#             "Improve server load",
#             "Create notifications",
#             "Boost ad revenue"
#         ]
#     }
# ]

# insert_questions(questions_lectures_6_7)

# %%
# # Generate 25 new questions not previously asked about topics from Lectures 6 + 7

# new_questions_lectures_6_7 = [
#     {
#         "question": "What is the main purpose of a tactical dashboard?",
#         "options": [
#             "Monitor mid-term performance and operations",
#             "Display real-time server activity",
#             "Visualize low-level system logs",
#             "Support strategic executive decisions"
#         ]
#     },
#     {
#         "question": "Which element enhances operant conditioning in a user interface?",
#         "options": [
#             "Consistent reward for specific actions",
#             "Background gradients",
#             "Hover animations",
#             "Invisible navigation"
#         ]
#     },
#     {
#         "question": "Which visual element is LEAST effective in capturing bottom-up attention?",
#         "options": [
#             "Subtle gray text",
#             "Flashing red alert",
#             "Large bold headline",
#             "Animated icon"
#         ]
#     },
#     {
#         "question": "What is one key principle in aligning mental models with system design?",
#         "options": [
#             "Use metaphors familiar to the user",
#             "Rely on backend logic alone",
#             "Avoid using icons",
#             "Ignore user feedback"
#         ]
#     },
#     {
#         "question": "Which kind of memory is most critical for following a multi-step process?",
#         "options": [
#             "Working memory",
#             "Iconic memory",
#             "Procedural memory",
#             "Echoic memory"
#         ]
#     },
#     {
#         "question": "Which behavior type is influenced by learned consequences?",
#         "options": [
#             "Operant behavior",
#             "Reflex response",
#             "Conditioned stimulus",
#             "Automated action"
#         ]
#     },
#     {
#         "question": "What does a high response time in Fitts’ Law suggest?",
#         "options": [
#             "Target is either too small or too far",
#             "User made a cognitive error",
#             "Icon size is too large",
#             "System response is slow"
#         ]
#     },
#     {
#         "question": "Which reinforcement strategy increases behavior through removal of a negative condition?",
#         "options": [
#             "Negative reinforcement",
#             "Positive punishment",
#             "Neutral feedback",
#             "Fixed interval feedback"
#         ]
#     },
#     {
#         "question": "In the context of UI, what does 'salience' refer to?",
#         "options": [
#             "How much an element stands out",
#             "The speed of rendering",
#             "Alignment of margins",
#             "Memory storage limits"
#         ]
#     },
#     {
#         "question": "Which action best supports user learning through positive reinforcement?",
#         "options": [
#             "Displaying a success message with a badge",
#             "Removing all on-screen hints",
#             "Resetting user progress",
#             "Disabling navigation"
#         ]
#     },
#     {
#         "question": "What is a key trait of model-free reinforcement learning?",
#         "options": [
#             "Behavior driven by trial and error without a system model",
#             "Fast pre-programmed decision-making",
#             "Immediate system response based on layout",
#             "Strategy defined by user interface guidelines"
#         ]
#     },
#     {
#         "question": "What is the most likely reason to use a modal interface?",
#         "options": [
#             "To require focused user interaction for a critical task",
#             "To reduce click-through rates",
#             "To allow background processes",
#             "To speed up loading times"
#         ]
#     },
#     {
#         "question": "Which display principle aligns with reducing user decision fatigue?",
#         "options": [
#             "Simplifying options and emphasizing defaults",
#             "Using complex animations",
#             "Providing raw data views",
#             "Adding more filters"
#         ]
#     },
#     {
#         "question": "Which cognitive load principle is violated when multiple tasks share the same interface area?",
#         "options": [
#             "Proximity compatibility",
#             "Redundancy gain",
#             "Visual contrast",
#             "Split-attention effect"
#         ]
#     },
#     {
#         "question": "What is the main purpose of classical conditioning in design psychology?",
#         "options": [
#             "Create predictable emotional associations with UI elements",
#             "Increase download speeds",
#             "Minimize button clicks",
#             "Activate all user senses"
#         ]
#     },
#     {
#         "question": "Which example best demonstrates a mental model mismatch?",
#         "options": [
#             "A 'trash' icon deletes permanently without warning",
#             "A settings menu is available on the top-right corner",
#             "Search opens a familiar modal window",
#             "Profile settings open on a new page"
#         ]
#     },
#     {
#         "question": "How does gamification improve user motivation?",
#         "options": [
#             "By leveraging goal achievement and reward systems",
#             "By forcing app usage",
#             "By disabling exit options",
#             "By hiding advanced features"
#         ]
#     },
#     {
#         "question": "Which interface element supports spatial memory reinforcement?",
#         "options": [
#             "Consistent menu location across screens",
#             "Changing icons randomly",
#             "Animated tooltips",
#             "Floating menus"
#         ]
#     },
#     {
#         "question": "What is a key benefit of aligning aesthetic design with usability?",
#         "options": [
#             "Users perceive the system as more functional",
#             "It reduces codebase size",
#             "It speeds up server rendering",
#             "It avoids the need for testing"
#         ]
#     },
#     {
#         "question": "Which principle is violated when screen layout is inconsistent across pages?",
#         "options": [
#             "Consistency",
#             "Redundancy gain",
#             "Modal simplicity",
#             "Fitts' optimization"
#         ]
#     },
#     {
#         "question": "What does the 'filter bubble' concept warn against in dashboards?",
#         "options": [
#             "Over-personalization reduces user exposure to diverse data",
#             "Charts with many colors are hard to interpret",
#             "Dashboards are slow to load",
#             "Filters are too difficult to apply"
#         ]
#     },
#     {
#         "question": "Which feedback style is most effective in shaping behavior?",
#         "options": [
#             "Immediate, specific, and positive",
#             "Randomly delayed feedback",
#             "General praise after 1 week",
#             "No feedback at all"
#         ]
#     },
#     {
#         "question": "Which UX concept focuses on how long an element remains in view before fading?",
#         "options": [
#             "Dwell time",
#             "Latency load",
#             "Frame rate",
#             "Compression ratio"
#         ]
#     },
#     {
#         "question": "Which visual design principle reduces distraction from less important elements?",
#         "options": [
#             "Visual hierarchy",
#             "Interactive filtering",
#             "Attention splitting",
#             "Primary affordance"
#         ]
#     },
#     {
#         "question": "What is the main difference between sensory and working memory?",
#         "options": [
#             "Duration and capacity for processing",
#             "Location on screen",
#             "How colorful the input is",
#             "How many senses are involved"
#         ]
#     }
# ]

# insert_questions(new_questions_lectures_6_7)

# %%
# def migrate_add_topics():
#     """
#     Migrate the database to add a topics table and link all existing questions to the 'design' topic.
#     """
#     conn = sqlite3.connect(DB_PATH)
#     cursor = conn.cursor()

#     # 1. Create topics table
#     cursor.execute('''
#         CREATE TABLE IF NOT EXISTS topics (
#             id INTEGER PRIMARY KEY AUTOINCREMENT,
#             name TEXT NOT NULL UNIQUE
#         )
#     ''')

#     # 2. Insert 'design' topic if not exists
#     cursor.execute('INSERT OR IGNORE INTO topics (name) VALUES (?)', ('design',))
#     cursor.execute('SELECT id FROM topics WHERE name = ?', ('design',))
#     design_topic_id = cursor.fetchone()[0]

#     # 3. Add topic_id column to questions if not exists
#     cursor.execute("PRAGMA table_info(questions)")
#     columns = [col[1] for col in cursor.fetchall()]
#     if 'topic_id' not in columns:
#         cursor.execute('ALTER TABLE questions ADD COLUMN topic_id INTEGER')

#     # 4. Set topic_id for all existing questions to 'design'
#     cursor.execute('UPDATE questions SET topic_id = ?', (design_topic_id,))

#     # 5. (Optional) Add foreign key constraint (SQLite doesn't support adding FK to existing table directly)
#     # This step is for documentation; to enforce FK, a new table would need to be created and data copied.

#     conn.commit()
#     conn.close()

# %%
# migrate_add_topics()

# %%
def insert_topic(name: str) -> int:
    """
    Insert a topic by name if it does not exist and return its ID.
    """
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS topics (
            id INTEGER PRIMARY KEY AUTOINCREMENT,
            name TEXT NOT NULL UNIQUE
        )
    ''')
    cursor.execute('INSERT OR IGNORE INTO topics (name) VALUES (?)', (name,))
    cursor.execute('SELECT id FROM topics WHERE name = ?', (name,))
    topic_id = cursor.fetchone()[0]
    conn.commit()
    conn.close()
    return topic_id

def insert_questions_with_topic(questions: list, topic_name: str) -> None:
    """
    Insert questions and their options into the database, associating them with a topic.
    If the topic does not exist, it will be created.
    """
    topic_id = insert_topic(topic_name)
    conn = sqlite3.connect(DB_PATH)
    cursor = conn.cursor()
    for question_data in questions:
        cursor.execute('INSERT INTO questions (question, topic_id) VALUES (?, ?)', (question_data["question"], topic_id))
        question_id = cursor.lastrowid
        option_id_answer = None
        for option in question_data["options"]:
            cursor.execute('INSERT INTO options (question_id, option_text) VALUES (?, ?)', (question_id, option))
            if option_id_answer is None:
                option_id_answer = cursor.lastrowid
        cursor.execute('INSERT INTO answers (question_id, option_id) VALUES (?, ?)', (question_id, option_id_answer))
    conn.commit()
    conn.close()

# %%
# insert_topic("marketing")

# %%
# questions_lecture1 = [
#     {
#         "question": "What is the primary goal of marketing?",
#         "options": [
#             "To create value and build profitable customer relationships",
#             "To produce as many goods as possible",
#             "To set the lowest price possible",
#             "To increase social media followers"
#         ]
#     },
#     {
#         "question": "A market is defined as:",
#         "options": [
#             "A set of actual and potential buyers of a product",
#             "A physical place where goods are sold",
#             "A set of all businesses in a given industry",
#             "A group of companies targeting the same audience"
#         ]
#     },
#     {
#         "question": "The selling concept focuses primarily on:",
#         "options": [
#             "Aggressive sales to drive short-term purchases",
#             "Long-term customer relationships",
#             "Product innovation",
#             "Mass production efficiency"
#         ]
#     },
#     {
#         "question": "Which of the following is an example of marketing myopia?",
#         "options": [
#             "A bookstore ignoring e-books to focus on printed books",
#             "A tech company developing new AI services",
#             "A brand engaging with customers on social media",
#             "A car company launching an electric vehicle line"
#         ]
#     },
#     {
#         "question": "The 4Ps of the marketing mix include:",
#         "options": [
#             "Product, Price, Place, Promotion",
#             "People, Positioning, Planning, Packaging",
#             "Production, Pricing, People, Planning",
#             "Proposition, Price, Purpose, Process"
#         ]
#     },
#     {
#         "question": "In marketing, customer-perceived value refers to:",
#         "options": [
#             "The difference between total benefits and total cost to the customer",
#             "How much the company charges",
#             "The cost of production",
#             "The resale value of a product"
#         ]
#     },
#     {
#         "question": "The societal marketing concept emphasizes:",
#         "options": [
#             "Delivering value in a way that improves both consumer and societal well-being",
#             "Short-term sales growth",
#             "Maximizing profits regardless of customer needs",
#             "Selling low-cost products"
#         ]
#     },
#     {
#         "question": "Market segmentation involves:",
#         "options": [
#             "Dividing the market into distinct groups of buyers with similar needs",
#             "Increasing the product price",
#             "Merging different target markets",
#             "Choosing a distribution channel"
#         ]
#     },
#     {
#         "question": "Customer equity is:",
#         "options": [
#             "The total combined lifetime values of all the company’s customers",
#             "The stock price of the company",
#             "The financial value of a brand's logo",
#             "The return on investment from a marketing campaign"
#         ]
#     },
#     {
#         "question": "Which concept starts with a well-defined market, focuses on customer needs, and integrates all marketing activities?",
#         "options": [
#             "Marketing concept",
#             "Production concept",
#             "Product concept",
#             "Selling concept"
#         ]
#     }
# ]
# insert_questions_with_topic(questions_lecture1, "marketing")

# %%
# questions_yes_no = [
#     {
#         "question": "Is customer engagement an important part of modern marketing strategy?",
#         "options": [
#             "Yes",
#             "No"
#         ]
#     },
#     {
#         "question": "Does the selling concept prioritize building long-term customer relationships?",
#         "options": [
#             "No",
#             "Yes"
#         ]
#     },
#     {
#         "question": "Is market segmentation the process of dividing a market into distinct groups with similar needs?",
#         "options": [
#             "Yes",
#             "No"
#         ]
#     },
#     {
#         "question": "Does customer equity refer to the sum of all a company's assets?",
#         "options": [
#             "No",
#             "Yes"
#         ]
#     },
#     {
#         "question": "Is the production concept based on the idea that consumers prefer products that are widely available and affordable?",
#         "options": [
#             "Yes",
#             "No"
#         ]
#     },
#     {
#         "question": "Is value proposition the set of benefits a brand promises to deliver to customers?",
#         "options": [
#             "Yes",
#             "No"
#         ]
#     },
#     {
#         "question": "Is customer satisfaction determined by the difference between expectations and perceived performance?",
#         "options": [
#             "Yes",
#             "No"
#         ]
#     },
#     {
#         "question": "Does the societal marketing concept ignore societal well-being?",
#         "options": [
#             "No",
#             "Yes"
#         ]
#     },
#     {
#         "question": "Is price one of the elements of the marketing mix?",
#         "options": [
#             "Yes",
#             "No"
#         ]
#     },
#     {
#         "question": "Is marketing myopia caused by focusing too much on customer experiences instead of the actual product?",
#         "options": [
#             "No",
#             "Yes"
#         ]
#     }
# ]
# insert_questions_with_topic(questions_yes_no, "marketing")

# %%
# questions_a = [
#     {
#         "question": "What is the main difference between a microenvironment and a macroenvironment in marketing?",
#         "options": [
#             "The microenvironment includes close actors like suppliers and customers, while the macroenvironment includes broader societal forces.",
#             "The macroenvironment is internal to the company, while the microenvironment is external.",
#             "Microenvironment factors are controlled by the government, while macroenvironment factors are not.",
#             "The microenvironment includes demographics, while the macroenvironment includes employees and managers."
#         ]
#     },
#     {
#         "question": "Which of the following is a characteristic of Generation X?",
#         "options": [
#             "They value experiences over possessions and are less responsive to advertising.",
#             "They are the wealthiest and most tech-savvy generation.",
#             "They are digital natives who blend online and offline experiences seamlessly.",
#             "They are known for being the biggest spenders and the most traditional consumers."
#         ]
#     },
#     {
#         "question": "What transforms a want into a demand?",
#         "options": [
#             "Purchasing power",
#             "Advertising influence",
#             "Government regulation",
#             "Product availability"
#         ]
#     },
#     {
#         "question": "Which generation is referred to as Millennials?",
#         "options": [
#             "Generation Y",
#             "Generation Z",
#             "Baby Boomers",
#             "Generation Alpha"
#         ]
#     },
#     {
#         "question": "What is the core focus of customer value–driven marketing?",
#         "options": [
#             "Creating value and building strong relationships with customers",
#             "Maximizing production and efficiency",
#             "Focusing only on product features",
#             "Minimizing marketing costs"
#         ]
#     },
#     {
#         "question": "Which generation is known for already influencing household purchasing decisions despite their young age?",
#         "options": [
#             "Generation Alpha",
#             "Generation X",
#             "Baby Boomers",
#             "Millennials"
#         ]
#     },
#     {
#         "question": "What is a 'market' in marketing terms?",
#         "options": [
#             "The group of actual and potential buyers of a product or service",
#             "The collection of sellers in a given industry",
#             "The number of stores selling a certain product",
#             "The space where economic exchanges occur physically"
#         ]
#     },
#     {
#         "question": "What do marketers exchange with customers to create relationships?",
#         "options": [
#             "Value",
#             "Money",
#             "Information",
#             "Discounts"
#         ]
#     },
#     {
#         "question": "Which of the following best describes the concept of 'needs'?",
#         "options": [
#             "States of felt deprivation",
#             "Luxury goods customers want to buy",
#             "The influence of advertising on purchasing behavior",
#             "Government policies affecting demand"
#         ]
#     },
#     {
#         "question": "Which environment includes technology, demographics, and cultural forces?",
#         "options": [
#             "Macroenvironment",
#             "Microenvironment",
#             "Internal environment",
#             "Corporate environment"
#         ]
#     }
# ]

# questions_b = [
#     {
#         "question": "Marketing involves understanding and satisfying customer needs.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Generation Alpha consists of individuals born before 1990.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Demographic trends such as aging populations affect marketing strategies.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "The microenvironment includes broad societal forces that shape market conditions.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Exchange in marketing refers to obtaining a desired product by offering something of value in return.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Millennials are known for being tech-savvy and desiring authentic brand experiences.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Customer satisfaction has no impact on repurchase behavior or brand loyalty.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Markets consist only of people who have already purchased a product.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "The macroenvironment includes factors like customers and suppliers.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Generation Z blends online and offline experiences and values authenticity.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     }
# ]

# insert_questions_with_topic(questions_a, "marketing")
# insert_questions_with_topic(questions_b, "marketing")

# %%
# questions_ch4 = []

# # Type A Questions (Multiple Choice, correct answer always first)
# questions_a_ch4 = [
#     {
#         "question": "What is the main purpose of customer insights in marketing?",
#         "options": [
#             "To gain a deep understanding of customer needs and wants",
#             "To increase advertising budgets",
#             "To simplify product designs",
#             "To reduce the need for data collection"
#         ]
#     },
#     {
#         "question": "Which of the following is considered internal data in marketing?",
#         "options": [
#             "Sales transactions and customer service records",
#             "Social media monitoring",
#             "Industry research reports",
#             "Benchmarking competitors"
#         ]
#     },
#     {
#         "question": "What is the role of competitive marketing intelligence?",
#         "options": [
#             "To monitor and analyze publicly available information about competitors",
#             "To hack competitors’ systems",
#             "To track customer phone numbers",
#             "To monitor internal emails"
#         ]
#     },
#     {
#         "question": "What is the purpose of exploratory research?",
#         "options": [
#             "To help define problems and suggest hypotheses",
#             "To estimate market size",
#             "To test product quality",
#             "To verify financial records"
#         ]
#     },
#     {
#         "question": "Which data collection method uses trained observers in natural environments?",
#         "options": [
#             "Ethnographic research",
#             "Survey research",
#             "Experimental research",
#             "Online panel interviews"
#         ]
#     },
#     {
#         "question": "Which is an example of primary data?",
#         "options": [
#             "Survey results collected from new customers",
#             "Historical sales reports",
#             "Government census data",
#             "Published market analysis"
#         ]
#     },
#     {
#         "question": "Which approach involves comparing groups exposed to different marketing stimuli?",
#         "options": [
#             "Experimental research",
#             "Observational research",
#             "Survey research",
#             "Ethnographic research"
#         ]
#     },
#     {
#         "question": "Which type of sample ensures each person has an equal chance of selection?",
#         "options": [
#             "Simple random sample",
#             "Quota sample",
#             "Convenience sample",
#             "Judgment sample"
#         ]
#     },
#     {
#         "question": "Which generation technology does Starbucks use for personalized customer interaction?",
#         "options": [
#             "Artificial Intelligence",
#             "Blockchain",
#             "Virtual Reality",
#             "3D Printing"
#         ]
#     },
#     {
#         "question": "Which platform is an example of an online customer community?",
#         "options": [
#             "bulbshare.com",
#             "Google Ads",
#             "SurveyMonkey",
#             "Mailchimp"
#         ]
#     },
#     {
#         "question": "What is the advantage of online experiments like A/B testing?",
#         "options": [
#             "They are low-cost and simple to implement",
#             "They require no sample planning",
#             "They eliminate the need for analysis",
#             "They are only used for focus groups"
#         ]
#     },
#     {
#         "question": "What does 'Voice of the Customer' (VoC) refer to?",
#         "options": [
#             "Customer feedback and sentiment across various touchpoints",
#             "Instructions for customer service agents",
#             "Recorded phone calls only",
#             "Competitor promotional materials"
#         ]
#     },
#     {
#         "question": "What is digital text analysis primarily used for?",
#         "options": [
#             "Analyzing large volumes of unstructured online content",
#             "Designing infographics",
#             "Sending newsletters",
#             "Formatting reports"
#         ]
#     },
#     {
#         "question": "Which type of sampling is easiest but less accurate?",
#         "options": [
#             "Convenience sampling",
#             "Stratified sampling",
#             "Cluster sampling",
#             "Random sampling"
#         ]
#     },
#     {
#         "question": "What is a data lake?",
#         "options": [
#             "A central repository for storing large, varied datasets used for insights",
#             "A cloud marketing automation tool",
#             "An AI-powered chatbot",
#             "A type of social media metric"
#         ]
#     }
# ]

# # Type B Questions (True/False, correct answer always first)
# questions_b_ch4 = [
#     {
#         "question": "Customer insights help businesses gain a competitive advantage.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Marketing research only uses secondary data sources.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Survey research is still the most commonly used method for primary data collection.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "A cluster sample includes everyone in the population.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Artificial Intelligence can personalize customer experiences in real-time.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Ethnographic research is conducted only in labs.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Big Data can include social media activity, sensor data, and customer interactions.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Online marketing research methods can include mobile surveys and online panels.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Quota sampling is a probability-based sampling method.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Voice of Customer programs involve collecting structured and unstructured feedback.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     }
# ]

# # Combine all questions into one variable
# questions_ch4 = questions_a_ch4 + questions_b_ch4

# # Insert the questions into the database
# insert_questions_with_topic(questions_ch4, "marketing")

# %%
# # Type A (Multiple Choice) Questions - correct answer is always first
# questions_a_lesson2 = [
#     {
#         "question": "What is a product in marketing terms?",
#         "options": [
#             "Anything that can be offered to a market to satisfy a need or want",
#             "Only physical goods sold in stores",
#             "Only services provided by a business",
#             "A strategy used to promote brands"
#         ]
#     },
#     {
#         "question": "What defines a service?",
#         "options": [
#             "An intangible activity or benefit offered for sale",
#             "A physical item sold in a store",
#             "A tangible product with added value",
#             "A bundle of features and accessories"
#         ]
#     },
#     {
#         "question": "What is an experience in marketing?",
#         "options": [
#             "A market offering with strong emotional or sensory impact over time",
#             "A tangible product that can be measured",
#             "A customer service phone call",
#             "A discount given at checkout"
#         ]
#     },
#     {
#         "question": "Which of the following is NOT one of the three levels of product planning?",
#         "options": [
#             "Service guarantee",
#             "Core benefit",
#             "Actual product",
#             "Augmented product"
#         ]
#     },
#     {
#         "question": "What distinguishes consumer products from industrial products?",
#         "options": [
#             "The purpose for which the product is purchased",
#             "The cost of production",
#             "The location of the purchase",
#             "The number of units sold"
#         ]
#     },
#     {
#         "question": "Which of the following is an industrial product?",
#         "options": [
#             "Capital items used in production",
#             "Shoes sold to retail customers",
#             "Fast food items",
#             "Cosmetic products"
#         ]
#     },
#     {
#         "question": "What are the three levels of product/service decisions?",
#         "options": [
#             "Individual product, product line, product mix",
#             "Pricing, promotion, distribution",
#             "Features, price, packaging",
#             "Retail, wholesale, B2B"
#         ]
#     },
#     {
#         "question": "What is the Service Profit Chain concept?",
#         "options": [
#             "Satisfied employees lead to better customer service and profitability",
#             "Customers create profits by referring others",
#             "Brands that advertise more have better profits",
#             "Businesses profit more when they lower prices"
#         ]
#     },
#     {
#         "question": "What makes services different from products in marketing?",
#         "options": [
#             "Services are intangible and depend on buyer-seller interaction",
#             "Services are easier to standardize",
#             "Services are always cheaper than products",
#             "Services do not require branding"
#         ]
#     },
#     {
#         "question": "What is brand equity?",
#         "options": [
#             "The value customers assign to a brand based on perception and loyalty",
#             "The legal ownership of a brand name",
#             "The amount of money invested in brand marketing",
#             "The cost to develop a new brand"
#         ]
#     },
#     {
#         "question": "What indicates positive brand equity?",
#         "options": [
#             "Customers prefer the branded product over a generic one",
#             "The company lowers prices on its products",
#             "The brand has a long history",
#             "The logo is visually appealing"
#         ]
#     },
#     {
#         "question": "What is brand value?",
#         "options": [
#             "The total financial worth of the brand",
#             "The quality of the logo design",
#             "The promotional cost of branding",
#             "The packaging style of a brand"
#         ]
#     },
#     {
#         "question": "Which of the following is NOT a brand sponsorship strategy?",
#         "options": [
#             "Retail-only brands",
#             "National brands",
#             "Private labels",
#             "Co-branding"
#         ]
#     },
#     {
#         "question": "Which of the following is a brand development strategy?",
#         "options": [
#             "Line extension",
#             "Bulk discounting",
#             "Seasonal promotion",
#             "Reverse logistics"
#         ]
#     },
#     {
#         "question": "How did a Disney executive describe a brand?",
#         "options": [
#             "A living entity built over time through small gestures",
#             "A tool for running advertising",
#             "An expensive investment in logo design",
#             "A liability on a balance sheet"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_lesson2 = [
#     {
#         "question": "A service results in ownership of a physical product.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Consumer products are purchased for personal use.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "The augmented product includes additional services and benefits.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Industrial products are purchased primarily for personal enjoyment.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Brand equity can influence customer preferences and loyalty.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Services marketing relies only on the traditional 4Ps of marketing.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "A brand with negative brand equity is less preferred than a generic product.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Product classification depends solely on its price point.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "The Service Profit Chain links employee satisfaction to company profitability.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Line extension uses an existing brand for a new product in a different category.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     }
# ]

# # Combine all questions into one list
# questions_lesson2 = questions_a_lesson2 + questions_b_lesson2

# # Insert the questions into the database
# insert_questions_with_topic(questions_lesson2, "marketing")

# %%
# # Type A (Multiple Choice) Questions - correct answer is always first
# questions_a_b2b = [
#     {
#         "question": "What is a key difference between B2B and B2C marketing?",
#         "options": [
#             "B2B targets businesses and professionals, while B2C targets individual consumers",
#             "B2B uses emotional appeal primarily, while B2C uses ROI-based appeal",
#             "B2B has shorter sales cycles than B2C",
#             "B2B purchases involve low value and high volume"
#         ]
#     },
#     {
#         "question": "What does 'derived demand' mean in B2B markets?",
#         "options": [
#             "Demand that originates from the demand for consumer products",
#             "A sudden drop in product demand due to market shifts",
#             "A demand derived from advertising performance",
#             "Unexpected orders from international clients"
#         ]
#     },
#     {
#         "question": "Which platform is most commonly used for B2B marketing?",
#         "options": [
#             "LinkedIn",
#             "Facebook",
#             "Instagram",
#             "TikTok"
#         ]
#     },
#     {
#         "question": "What is a 'straight rebuy'?",
#         "options": [
#             "A routine purchase of the same product under the same terms",
#             "A completely new purchase requiring detailed evaluation",
#             "A new supplier selection with major changes",
#             "A product switch due to poor service"
#         ]
#     },
#     {
#         "question": "What role does a 'gatekeeper' play in a B2B buying center?",
#         "options": [
#             "Controls access to decision-makers and information",
#             "Makes the final purchasing decision",
#             "Influences the buyer with technical knowledge",
#             "Uses the product regularly"
#         ]
#     },
#     {
#         "question": "What does 'systems selling' refer to?",
#         "options": [
#             "Purchasing a complete solution from a single supplier",
#             "Selling services without hardware",
#             "Buying products in small parts from different suppliers",
#             "Creating a customer support system"
#         ]
#     },
#     {
#         "question": "Which content type is attracting the most investment among B2B marketers?",
#         "options": [
#             "Video",
#             "Audio",
#             "Infographics",
#             "Email newsletters"
#         ]
#     },
#     {
#         "question": "What is the goal of product-led growth (PLG)?",
#         "options": [
#             "To drive customer acquisition through the product itself",
#             "To eliminate marketing roles",
#             "To rely solely on external promotions",
#             "To outsource customer service"
#         ]
#     },
#     {
#         "question": "What is a characteristic of the B2B buying process?",
#         "options": [
#             "Longer and more structured than B2C",
#             "Based mostly on emotion and impulse",
#             "Limited to online channels only",
#             "No need for evaluation or approval"
#         ]
#     },
#     {
#         "question": "What percentage of B2B marketers use LinkedIn?",
#         "options": [
#             "80%",
#             "63%",
#             "52%",
#             "39%"
#         ]
#     },
#     {
#         "question": "Which function is typically handled by a Sales Development Representative (SDR)?",
#         "options": [
#             "Follow up with inbound sales leads",
#             "Execute corporate legal contracts",
#             "Manage billing operations",
#             "Analyze competitor data"
#         ]
#     },
#     {
#         "question": "Which of the following is a major touchpoint in B2B buying?",
#         "options": [
#             "Multiple stakeholder interactions",
#             "Browsing through social media ads",
#             "Comparing prices at retail stores",
#             "Watching television ads"
#         ]
#     },
#     {
#         "question": "What best describes the 'buying center'?",
#         "options": [
#             "A group of people involved in the purchasing decision",
#             "The location where products are bought",
#             "An online portal for orders",
#             "The headquarters of a company"
#         ]
#     },
#     {
#         "question": "What is a Marketing Qualified Lead (MQL)?",
#         "options": [
#             "A lead that has shown interest and meets basic engagement criteria",
#             "A customer who has made a purchase",
#             "A prospect contacted by a sales executive",
#             "A lead with no sales potential"
#         ]
#     },
#     {
#         "question": "Which of the following is true about emotions in B2B?",
#         "options": [
#             "Emotions like pride and risk influence B2B decisions",
#             "Emotions are not relevant in B2B markets",
#             "Only financial ROI matters in B2B",
#             "Emotions only affect B2C sales"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_b2b = [
#     {
#         "question": "The B2B buying process is generally shorter and less structured than B2C.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Systems selling involves purchasing components from multiple suppliers.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "In B2B, the product is often the main vehicle for growth in a product-led strategy.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Gatekeepers in a buying center typically approve budgets.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "LinkedIn is the most used social media platform for B2B marketing.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Derived demand in B2B originates from consumer demand.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "B2B markets consist of many small buyers rather than a few large ones.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Emotional factors like pride and security influence B2B buyers.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "An MQL is someone who has made a purchase.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Digital platforms and e-procurement are now standard in B2B purchases.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     }
# ]

# # Combine both into one variable
# questions_ch6_b2b = questions_a_b2b + questions_b_b2b

# # Insert the questions into the database
# insert_questions_with_topic(questions_ch6_b2b, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_lesson3 = [
#     {
#         "question": "What is the definition of retailing?",
#         "options": [
#             "All activities related to selling goods or services directly to consumers for personal use",
#             "Selling goods only through physical stores",
#             "Wholesale transactions between manufacturers",
#             "Only services delivered through mobile apps"
#         ]
#     },
#     {
#         "question": "What does ZMOT stand for in retail marketing?",
#         "options": [
#             "Zero Moment of Truth",
#             "Zone Management of Transactions",
#             "Zero Margin on Turnover",
#             "Zen Marketing Optimization Theory"
#         ]
#     },
#     {
#         "question": "What percentage of consumers make purchase decisions during micro-moments?",
#         "options": [
#             "73%",
#             "50%",
#             "85%",
#             "32%"
#         ]
#     },
#     {
#         "question": "What is omni-channel marketing?",
#         "options": [
#             "A seamless experience across physical, digital, and mobile retail channels",
#             "Promoting through newspapers and magazines",
#             "Selling only on social media",
#             "Offering limited products in physical stores"
#         ]
#     },
#     {
#         "question": "Which of the following is NOT a type of store retail classification?",
#         "options": [
#             "Online engagement score",
#             "Amount of service",
#             "Product line",
#             "Relative pricing"
#         ]
#     },
#     {
#         "question": "Which is an example of non-store retailing?",
#         "options": [
#             "Direct-mail marketing",
#             "Department store shopping",
#             "In-store kiosks",
#             "Mall walk-ins"
#         ]
#     },
#     {
#         "question": "What does STDP stand for in retailer marketing decisions?",
#         "options": [
#             "Segmentation, Targeting, Differentiation, Positioning",
#             "Sales, Target, Display, Profit",
#             "Strategy, Testing, Delivery, Pricing",
#             "Segmentation, Tactics, Demand, Promotion"
#         ]
#     },
#     {
#         "question": "What is included in product assortment decisions?",
#         "options": [
#             "Product variety, service mix, store atmosphere",
#             "Return policy, product label, licensing",
#             "Advertising budget, price tags, floor staff",
#             "Customer loyalty programs only"
#         ]
#     },
#     {
#         "question": "What are the two price strategies used in retail?",
#         "options": [
#             "High markup on low volume, low markup on high volume",
#             "Freemium and Premium",
#             "Dynamic pricing and cost-plus pricing",
#             "Loss leader and premium bundling"
#         ]
#     },
#     {
#         "question": "Which promotion method is associated with a 'Buy 3 pay for 2' offer?",
#         "options": [
#             "Sales promotion",
#             "Advertising",
#             "Public relations",
#             "Direct marketing"
#         ]
#     },
#     {
#         "question": "What is the most critical factor in retail store success?",
#         "options": [
#             "Location",
#             "Store size",
#             "Product packaging",
#             "Employee uniforms"
#         ]
#     },
#     {
#         "question": "What trend has shortened the life cycles of retail forms?",
#         "options": [
#             "Emergence of new consumer needs and behaviors",
#             "Increased government regulation",
#             "Longer production times",
#             "Global pandemics"
#         ]
#     },
#     {
#         "question": "What has led to the rise of megaretailers?",
#         "options": [
#             "Mass merchandisers, specialty stores, vertical systems, and online growth",
#             "Government subsidies to local businesses",
#             "Falling retail rents",
#             "Reduced digital marketing costs"
#         ]
#     },
#     {
#         "question": "Why do global retailers expand internationally?",
#         "options": [
#             "To grow their business through unique brand formats",
#             "To avoid local taxes",
#             "To close underperforming stores",
#             "To gain celebrity endorsements"
#         ]
#     },
#     {
#         "question": "What defines wholesaling?",
#         "options": [
#             "Selling goods/services to businesses for resale or use",
#             "Selling directly to end consumers",
#             "Retailing within factory outlets",
#             "Auctioning excess products"
#         ]
#     },
#     {
#         "question": "Which wholesaler type owns the goods it handles?",
#         "options": [
#             "Merchant wholesalers",
#             "Brokers",
#             "Agents",
#             "Manufacturer’s reps"
#         ]
#     },
#     {
#         "question": "What role do brokers play in wholesaling?",
#         "options": [
#             "They connect buyers and sellers without owning the goods",
#             "They own and resell merchandise",
#             "They handle shipping and warehousing",
#             "They offer marketing consultations"
#         ]
#     },
#     {
#         "question": "What is a key challenge faced by modern wholesalers?",
#         "options": [
#             "The need for greater operational efficiency",
#             "Too many customers walking in",
#             "Low demand for business supplies",
#             "Limited access to e-commerce"
#         ]
#     },
#     {
#         "question": "What decisions must wholesalers make like retailers?",
#         "options": [
#             "Product, price, promotion, place",
#             "Hiring policies, vendor licenses, CSR initiatives",
#             "R&D budgets, legal frameworks, tech partners",
#             "None, wholesalers do not market"
#         ]
#     },
#     {
#         "question": "What describes an agent’s role in wholesaling?",
#         "options": [
#             "Represents buyers or sellers long-term without taking ownership",
#             "Owns goods and resells at a markup",
#             "Provides consumer surveys",
#             "Creates digital advertisements"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_lesson3 = [
#     {
#         "question": "Retailing includes both online and in-store activities aimed at consumers.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "The retail apocalypse refers to an increase in store openings in urban areas.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Omni-channel marketing creates a seamless buying experience across channels.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Non-store retailing includes direct mail and telemarketing.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Store atmosphere is not considered in product assortment decisions.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Advertising is a form of public relations.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "The location of a retail store is critical to its success.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Wholesaling targets consumers directly through stores.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Merchant wholesalers take ownership of the products they sell.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Agents represent companies long-term but do not own inventory.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Modern wholesalers are focused on improving efficiency.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Direct-response TV marketing is a form of store retailing.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Sales promotions include discounts and bundle deals.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Brokers take title to the merchandise they handle.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Retailers and wholesalers use the same four P’s of marketing.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     }
# ]

# # Combine all questions into one variable
# questions_lesson3 = questions_a_lesson3 + questions_b_lesson3

# # Insert the questions into the database
# insert_questions_with_topic(questions_lesson3, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_ch7 = [
#     {
#         "question": "What is the purpose of market segmentation?",
#         "options": [
#             "To divide a market into distinct groups based on needs, characteristics, or behaviors",
#             "To price products based on competitor actions",
#             "To reduce marketing costs by targeting everyone",
#             "To create uniform offers for all customers"
#         ]
#     },
#     {
#         "question": "Which segmentation base divides the market by location?",
#         "options": [
#             "Geographic segmentation",
#             "Demographic segmentation",
#             "Behavioral segmentation",
#             "Psychographic segmentation"
#         ]
#     },
#     {
#         "question": "Which company ran a hyperlocal campaign near competitors?",
#         "options": [
#             "Burger King",
#             "Starbucks",
#             "Amazon",
#             "Tesla"
#         ]
#     },
#     {
#         "question": "Which segmentation base includes variables like age, gender, and income?",
#         "options": [
#             "Demographic",
#             "Behavioral",
#             "Psychographic",
#             "Geographic"
#         ]
#     },
#     {
#         "question": "Psychographic segmentation considers:",
#         "options": [
#             "Lifestyle and personality",
#             "User status and loyalty",
#             "Gender and income",
#             "Geography and climate"
#         ]
#     },
#     {
#         "question": "Behavioral segmentation is based on:",
#         "options": [
#             "Knowledge, usage, attitudes, or responses",
#             "Gender and education level",
#             "Location and neighborhood",
#             "Income and profession"
#         ]
#     },
#     {
#         "question": "Multiple segmentation uses:",
#         "options": [
#             "A mix of variables like geographic, demographic, behavioral, etc.",
#             "Only lifestyle data",
#             "One variable per campaign",
#             "Sales data alone"
#         ]
#     },
#     {
#         "question": "What is a requirement for effective segmentation?",
#         "options": [
#             "Measurable",
#             "Flexible",
#             "Expensive",
#             "Static"
#         ]
#     },
#     {
#         "question": "Targeting involves:",
#         "options": [
#             "Selecting which market segments to serve",
#             "Creating TV ads for all markets",
#             "Eliminating segmentation",
#             "Defining geographic boundaries"
#         ]
#     },
#     {
#         "question": "Which targeting strategy focuses on several segments with separate offers?",
#         "options": [
#             "Differentiated marketing",
#             "Mass marketing",
#             "Niche marketing",
#             "Micromarketing"
#         ]
#     },
#     {
#         "question": "Which company uses different hotel brands for different segments?",
#         "options": [
#             "InterContinental Hotels Group",
#             "Nike",
#             "Domino’s",
#             "Meta"
#         ]
#     },
#     {
#         "question": "Concentrated marketing targets:",
#         "options": [
#             "A large share of a small market",
#             "Everyone with one offer",
#             "Every market segment equally",
#             "Only online shoppers"
#         ]
#     },
#     {
#         "question": "Micromarketing includes:",
#         "options": [
#             "Local and individual marketing",
#             "Selling to mass markets",
#             "Celebrity influencer marketing",
#             "Outdoor advertising only"
#         ]
#     },
#     {
#         "question": "What is positioning?",
#         "options": [
#             "The place a brand occupies in the consumer’s mind relative to competitors",
#             "The location of the retail store",
#             "The cost of market research",
#             "A way to evaluate employee performance"
#         ]
#     },
#     {
#         "question": "Positioning maps are used to:",
#         "options": [
#             "Visualize consumer perceptions of brands",
#             "List ad placements",
#             "Predict market size",
#             "Track sales channels"
#         ]
#     },
#     {
#         "question": "Which company uses 'ultimate driving machine' as a value proposition?",
#         "options": [
#             "BMW",
#             "Ford",
#             "Honda",
#             "Tesla"
#         ]
#     },
#     {
#         "question": "What should a competitive advantage be?",
#         "options": [
#             "Important, Distinctive, Superior, Communicable, Preemptive, Affordable, Profitable",
#             "Common, Simple, Inexpensive",
#             "Non-measurable and subtle",
#             "Technological only"
#         ]
#     },
#     {
#         "question": "Value proposition answers:",
#         "options": [
#             "Why should I buy your brand?",
#             "Where is your brand sold?",
#             "Who founded the company?",
#             "What is the warranty duration?"
#         ]
#     },
#     {
#         "question": "What does a positioning statement include?",
#         "options": [
#             "Target, brand, concept, and point of difference",
#             "Employee names, branch offices, logos",
#             "Sales projections and pricing",
#             "All product SKUs"
#         ]
#     },
#     {
#         "question": "Which company customizes shoes based on 3D scans?",
#         "options": [
#             "FitMyFoot",
#             "Nike",
#             "Reebok",
#             "Zappos"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_ch7 = [
#     {
#         "question": "Demographic segmentation considers variables like age, income, and gender.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Behavioral segmentation is unrelated to consumer usage patterns.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Micromarketing aims to tailor products for broad mass markets.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Positioning is based solely on price and quality.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "A company may choose a niche market to focus its efforts effectively.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Differentiated marketing is more expensive and complex than concentrated marketing.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Geographic segmentation divides customers by lifestyle preferences.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Positioning maps help marketers visualize customer perceptions.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "A value proposition explains the technical specifications of the product.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Effective segmentation should be measurable and actionable.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Acxiom and Experian provide multivariable segmentation tools.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "All brands should use the same positioning strategy for all market segments.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "One-to-one marketing is also known as mass customization.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Differentiation can be based on product, services, people, or image.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Facebook, WhatsApp, and Instagram serve the exact same market segment.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     }
# ]

# # Combine into one list
# questions_ch7 = questions_a_ch7 + questions_b_ch7

# # Insert the questions into the database
# insert_questions_with_topic(questions_ch7, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_lesson4 = [
#     {
#         "question": "What are the 4Ps in the marketing mix?",
#         "options": [
#             "Product, Price, Place, Promotion",
#             "People, Profit, Planning, Product",
#             "Positioning, Pricing, Platform, Promotion",
#             "Purpose, Production, Place, Profit"
#         ]
#     },
#     {
#         "question": "What is the first step in managing the 'Product' component?",
#         "options": [
#             "Defining the product and its features",
#             "Launching a TV campaign",
#             "Setting the price",
#             "Choosing the store location"
#         ]
#     },
#     {
#         "question": "Why is it important to understand a product’s life cycle?",
#         "options": [
#             "It helps shape the marketing approach at different stages",
#             "It determines the company’s legal obligations",
#             "It replaces the need for customer research",
#             "It affects employee hiring processes"
#         ]
#     },
#     {
#         "question": "Which product revolutionized digital music consumption?",
#         "options": [
#             "iPod",
#             "Walkman",
#             "MP3 CD",
#             "Zune"
#         ]
#     },
#     {
#         "question": "What is price defined as in marketing?",
#         "options": [
#             "The amount consumers are willing to pay for a product",
#             "The cost of manufacturing plus profit",
#             "The suggested retail price",
#             "The price printed on the packaging"
#         ]
#     },
#     {
#         "question": "What is the effect of setting a high price?",
#         "options": [
#             "It can create an image of luxury or exclusivity",
#             "It guarantees higher sales volume",
#             "It reduces production costs",
#             "It eliminates the need for advertising"
#         ]
#     },
#     {
#         "question": "Which pricing strategy might attract more consumers to try a product?",
#         "options": [
#             "Lower pricing",
#             "Dynamic pricing",
#             "Price skimming",
#             "Bundle pricing"
#         ]
#     },
#     {
#         "question": "What risk is associated with excessive discounting?",
#         "options": [
#             "It may make the product seem less desirable",
#             "It increases brand loyalty",
#             "It improves inventory accuracy",
#             "It raises the product's luxury perception"
#         ]
#     },
#     {
#         "question": "What is 'Place' concerned with in the 4Ps?",
#         "options": [
#             "Where and how the product is available to customers",
#             "Where the company is headquartered",
#             "When the product was first manufactured",
#             "Where employees are trained"
#         ]
#     },
#     {
#         "question": "Where would a luxury cosmetic brand likely prefer to be sold?",
#         "options": [
#             "Sephora",
#             "Walmart",
#             "Dollar Tree",
#             "Convenience stores"
#         ]
#     },
#     {
#         "question": "What famous movie helped boost BMW Z3 sales?",
#         "options": [
#             "GoldenEye",
#             "The Fast and the Furious",
#             "Skyfall",
#             "Mission Impossible"
#         ]
#     },
#     {
#         "question": "What does efficient distribution lead to?",
#         "options": [
#             "Good customer experience and competitive advantage",
#             "Higher warehouse costs",
#             "Increased manual processing",
#             "More legal documentation"
#         ]
#     },
#     {
#         "question": "Which of the following is a direct channel?",
#         "options": [
#             "Selling via the company’s own website",
#             "Selling through a supermarket",
#             "Selling via a distributor",
#             "Selling through a wholesaler"
#         ]
#     },
#     {
#         "question": "What is the primary goal of promotion?",
#         "options": [
#             "To communicate product value and necessity to consumers",
#             "To reduce production costs",
#             "To determine product pricing",
#             "To eliminate competition"
#         ]
#     },
#     {
#         "question": "Which of the following is part of promotional tools?",
#         "options": [
#             "Advertising and public relations",
#             "Product placement and packaging",
#             "Pricing and discounts",
#             "Employee management"
#         ]
#     },
#     {
#         "question": "What does 'placement' also refer to?",
#         "options": [
#             "Advertising in the right media",
#             "Putting a label on the box",
#             "Training new employees",
#             "Organizing inventory"
#         ]
#     },
#     {
#         "question": "Which is NOT one of the 4P’s?",
#         "options": [
#             "People",
#             "Product",
#             "Place",
#             "Price"
#         ]
#     },
#     {
#         "question": "What strategy would make a product seem affordable and high volume?",
#         "options": [
#             "Mass production at an affordable price",
#             "Luxury bundling",
#             "Premium pricing",
#             "Exclusive online launches"
#         ]
#     },
#     {
#         "question": "What role does the product type play?",
#         "options": [
#             "It affects pricing, placement, and promotion",
#             "It determines tax strategy",
#             "It eliminates advertising needs",
#             "It reduces product testing time"
#         ]
#     },
#     {
#         "question": "Why is the 4Ps model important?",
#         "options": [
#             "It guides companies in introducing and marketing their products effectively",
#             "It replaces the need for budgeting",
#             "It prevents economic inflation",
#             "It automates supply chain processes"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_lesson4 = [
#     {
#         "question": "The 4P’s include Product, Price, Place, and Promotion.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Understanding the product’s life cycle is irrelevant for marketing strategy.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "A high price can help create an image of exclusivity.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Discounting always improves the perception of a product.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Place includes both the physical location of the product and its distribution strategy.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "BMW Z3 sales increased after appearing in a James Bond movie.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Efficient distribution gives companies a competitive advantage.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Indirect channels mean the company sells directly to the customer.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Promotion includes advertising and public relations only.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Mass production at a low price is an example of a cost-based strategy.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Product type does not affect placement or pricing strategies.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Placement refers only to product location on store shelves.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Promotion helps consumers understand why they need a product.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Luxury brands prefer to be placed in low-cost discount stores.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Direct channels involve selling through intermediaries.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     }
# ]

# # Combine all questions
# questions_lesson4 = questions_a_lesson4 + questions_b_lesson4

# insert_questions_with_topic(questions_lesson4, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_ch9 = [
#     {
#         "question": "What are the two main ways to obtain new products?",
#         "options": [
#             "Acquisition and new product development",
#             "Innovation and promotion",
#             "Commercialization and distribution",
#             "Licensing and market segmentation"
#         ]
#     },
#     {
#         "question": "What is the first step in the new product development process?",
#         "options": [
#             "Idea generation",
#             "Test marketing",
#             "Concept development",
#             "Commercialization"
#         ]
#     },
#     {
#         "question": "Which company uses customer-submitted ideas for product development?",
#         "options": [
#             "LEGO",
#             "Apple",
#             "Coca-Cola",
#             "Ford"
#         ]
#     },
#     {
#         "question": "What framework is used in idea screening?",
#         "options": [
#             "R-W-W (Real, Win, Worth)",
#             "STP (Segmentation, Targeting, Positioning)",
#             "AIDA (Attention, Interest, Desire, Action)",
#             "SWOT"
#         ]
#     },
#     {
#         "question": "Which stage tests the product in a real-world market setting?",
#         "options": [
#             "Test marketing",
#             "Commercialization",
#             "Business analysis",
#             "Concept development"
#         ]
#     },
#     {
#         "question": "What is commercialization?",
#         "options": [
#             "Introducing the product to the market",
#             "Testing product ideas",
#             "Researching competitor pricing",
#             "Developing internal prototypes"
#         ]
#     },
#     {
#         "question": "In which stage of the product life cycle are sales low and costs high?",
#         "options": [
#             "Introduction",
#             "Growth",
#             "Maturity",
#             "Decline"
#         ]
#     },
#     {
#         "question": "What characterizes the growth stage of the product life cycle?",
#         "options": [
#             "Increasing sales and new competitors",
#             "Decreasing profits and withdrawal",
#             "High promotion costs and no revenue",
#             "Consumer disinterest and poor design"
#         ]
#     },
#     {
#         "question": "What is a common strategy in the maturity stage?",
#         "options": [
#             "Modifying the product, market, or mix",
#             "Rapid withdrawal",
#             "No advertising",
#             "Eliminating all competition"
#         ]
#     },
#     {
#         "question": "What describes a fad?",
#         "options": [
#             "Short-lived product trend with rapid rise and fall",
#             "Long-term style adoption",
#             "Product with growing brand loyalty",
#             "Classic product with high sales"
#         ]
#     },
#     {
#         "question": "What is a characteristic of radical innovation?",
#         "options": [
#             "Creates new markets with disruptive technology",
#             "Improves existing products with minor tweaks",
#             "Focuses only on pricing models",
#             "Avoids market feedback"
#         ]
#     },
#     {
#         "question": "Which pricing model is often used in radical innovation?",
#         "options": [
#             "Value-based or ROI-driven pricing",
#             "Skimming strategy only",
#             "Hourly rate pricing",
#             "Competitor-based pricing"
#         ]
#     },
#     {
#         "question": "What is the first step in the individual adoption process?",
#         "options": [
#             "Awareness of the innovation",
#             "Evaluation of the product",
#             "Purchase decision",
#             "Trial usage"
#         ]
#     },
#     {
#         "question": "Which adopter group is most willing to take risks and try new products?",
#         "options": [
#             "Innovators",
#             "Early majority",
#             "Laggards",
#             "Late adopters"
#         ]
#     },
#     {
#         "question": "What does the Bass Model predict?",
#         "options": [
#             "How innovations spread through a population",
#             "Stock market behavior",
#             "Advertising ROI",
#             "Product defects"
#         ]
#     },
#     {
#         "question": "What is 'crossing the chasm' in product adoption?",
#         "options": [
#             "Moving from early adopters to mainstream market",
#             "Marketing during decline stage",
#             "Creating early buzz",
#             "Defining technical specs"
#         ]
#     },
#     {
#         "question": "What does servitization refer to?",
#         "options": [
#             "Combining product and services into a unified offer",
#             "Reducing product packaging",
#             "Outsourcing manufacturing",
#             "Increasing product shelf life"
#         ]
#     },
#     {
#         "question": "When is test marketing least likely to be used?",
#         "options": [
#             "For simple line extensions",
#             "For a product with high investment",
#             "When there is uncertainty",
#             "For a national launch"
#         ]
#     },
#     {
#         "question": "Which company used meal planning apps to extend product use?",
#         "options": [
#             "Campbell Soup",
#             "Nestle",
#             "Apple",
#             "Starbucks"
#         ]
#     },
#     {
#         "question": "What does the potential market exclude?",
#         "options": [
#             "Immunes and non-adopters",
#             "Early adopters",
#             "Sales projections",
#             "Repeat customers"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_ch9 = [
#     {
#         "question": "Acquisition and internal development are both methods of creating new products.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Open innovation includes sourcing ideas from customers and partners.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Product concepts are vague summaries of potential product features.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Crowdfunding is a tool used during commercialization.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Fads typically have long-term popularity in the market.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Radical innovation creates entirely new categories and use cases.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Early adopters are usually skeptical and wait for product reviews.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "The Bass model incorporates both innovation and imitation in adoption.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Servitization means reducing product costs to improve accessibility.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Campbell's app helped promote greater soup usage via meal planning.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "The chasm in adoption occurs between innovators and early adopters.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Word of mouth plays a major role in the adoption process.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Imitators are modeled in the Bass Model as independent of other adopters.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Test marketing is never necessary when confidence is high.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "The product life cycle includes stages such as introduction, growth, maturity, and decline.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     }
# ]

# # Combine and display
# questions_ch9 = questions_a_ch9 + questions_b_ch9

# insert_questions_with_topic(questions_ch9, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_lesson5 = [
#     {
#         "question": "What is digital marketing primarily focused on?",
#         "options": [
#             "Engaging directly with targeted consumers using technology",
#             "Increasing the price of digital products",
#             "Eliminating traditional marketing",
#             "Restricting customer access to physical stores"
#         ]
#     },
#     {
#         "question": "Which company operates multiple travel brands like Expedia and trivago?",
#         "options": [
#             "Expedia Group",
#             "Booking.com",
#             "Airbnb",
#             "Kayak"
#         ]
#     },
#     {
#         "question": "One benefit of digital marketing for buyers is:",
#         "options": [
#             "Convenience and shopping anytime, anywhere",
#             "High-priced exclusive products",
#             "No return policy",
#             "Limited product choices"
#         ]
#     },
#     {
#         "question": "What is a key seller benefit of digital marketing?",
#         "options": [
#             "Access to new markets and customer data",
#             "Dependence on a single retail channel",
#             "No data collection",
#             "Higher inventory costs"
#         ]
#     },
#     {
#         "question": "What is a 'digital persona'?",
#         "options": [
#             "A data-based representation of a customer",
#             "A chatbot",
#             "A product review system",
#             "An influencer profile"
#         ]
#     },
#     {
#         "question": "Omni-channel behavior refers to:",
#         "options": [
#             "Consumer movement between physical and digital platforms",
#             "Shopping only through social media",
#             "Buying in physical stores only",
#             "Browsing on one platform but not purchasing"
#         ]
#     },
#     {
#         "question": "What tool helps marketers test different versions of a tactic?",
#         "options": [
#             "A/B testing",
#             "Heatmap analysis",
#             "Google Earth",
#             "CRM export"
#         ]
#     },
#     {
#         "question": "What is an example of a marketing website?",
#         "options": [
#             "An e-commerce site with reviews and product filters",
#             "A wiki with no sales features",
#             "A government service portal",
#             "A newspaper homepage"
#         ]
#     },
#     {
#         "question": "What is programmatic advertising?",
#         "options": [
#             "Automated real-time ad buying",
#             "Manual selection of ad placements",
#             "Print-based ad purchasing",
#             "Public relations campaigns"
#         ]
#     },
#     {
#         "question": "What is the main challenge of email marketing?",
#         "options": [
#             "Spam and low open rates",
#             "Too expensive to implement",
#             "Hard to track performance",
#             "Requires TV ads"
#         ]
#     },
#     {
#         "question": "Which medium accounts for most internet traffic?",
#         "options": [
#             "Online video",
#             "Podcasts",
#             "Blogs",
#             "Text-based websites"
#         ]
#     },
#     {
#         "question": "Influencers often promote brands through:",
#         "options": [
#             "Blogs and forums",
#             "Press releases",
#             "Government channels",
#             "E-learning platforms"
#         ]
#     },
#     {
#         "question": "What is a benefit of social media marketing?",
#         "options": [
#             "Immediate, targeted, and cost-effective engagement",
#             "Slow communication",
#             "High printing costs",
#             "One-way messaging only"
#         ]
#     },
#     {
#         "question": "JetBlue is known for:",
#         "options": [
#             "Fast social media responses",
#             "Selling mobile phones",
#             "Streaming exclusive shows",
#             "Shipping clothing worldwide"
#         ]
#     },
#     {
#         "question": "What is a challenge in social media marketing?",
#         "options": [
#             "User-controlled platforms that can backfire on brands",
#             "Unreachable audiences",
#             "Too much email marketing",
#             "No analytics tools"
#         ]
#     },
#     {
#         "question": "Mobile marketing uses:",
#         "options": [
#             "Smartphones and tablets to deliver content to consumers",
#             "Landline phones only",
#             "Billboards in metro stations",
#             "Direct mail"
#         ]
#     },
#     {
#         "question": "What regulation focuses on protecting user data privacy in the EU?",
#         "options": [
#             "GDPR",
#             "FCC",
#             "COPPA",
#             "DMCA"
#         ]
#     },
#     {
#         "question": "What type of marketing platform is the metaverse?",
#         "options": [
#             "Immersive and interactive",
#             "Static only",
#             "Used for spreadsheets",
#             "TV advertising platform"
#         ]
#     },
#     {
#         "question": "Which platform delivers real-time, interest-based ads using automation?",
#         "options": [
#             "Programmatic advertising",
#             "Banner swaps",
#             "Spam bots",
#             "Email blasts"
#         ]
#     },
#     {
#         "question": "What makes a website user experience successful?",
#         "options": [
#             "Usability, visual appeal, and helpful content",
#             "Pop-up ads and automatic videos",
#             "Minimal product info",
#             "Complicated navigation"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_lesson5 = [
#     {
#         "question": "Digital marketing enables real-time targeting and engagement.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Buyers find digital marketing inconvenient due to its 24/7 availability.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Digital personas help marketers understand their audience.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Experimentation like A/B testing helps reduce marketing risks.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "SEO stands for Social Engagement Optimization.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Email marketing is still one of the highest ROI digital channels.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Social media marketing requires brands to earn audience trust.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Online video marketing declined after COVID.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Mobile marketing only works on desktop devices.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Blogs can help build authentic brand communities.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "The metaverse offers no value to marketing efforts.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "JetBlue uses social media to respond quickly to customer inquiries.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Permission-based email marketing helps avoid spam issues.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "One challenge in omni-channel behavior tracking is data privacy.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "GDPR and COPPA are regulations aimed at protecting user data.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     }
# ]

# # Combine and display
# questions_lesson5 = questions_a_lesson5 + questions_b_lesson5

# insert_questions_with_topic(questions_lesson5, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_pricing = [
#     {
#         "question": "What is price in marketing terms?",
#         "options": [
#             "The amount of money charged for a product or service",
#             "The fixed cost of manufacturing",
#             "The budget set by the finance department",
#             "The cost of advertising a product"
#         ]
#     },
#     {
#         "question": "Which pricing strategy is based on customer perceptions of value?",
#         "options": [
#             "Value-based pricing",
#             "Cost-based pricing",
#             "Competition-based pricing",
#             "Psychological pricing"
#         ]
#     },
#     {
#         "question": "What is 'Everyday Low Pricing' (EDLP)?",
#         "options": [
#             "Consistent low prices with few or no temporary discounts",
#             "Frequent sales and high markups",
#             "Low introductory pricing followed by high prices",
#             "Setting prices below cost"
#         ]
#     },
#     {
#         "question": "What is the purpose of 'value-added pricing'?",
#         "options": [
#             "To attach features that justify higher prices",
#             "To match competitor prices",
#             "To offer the lowest prices in the market",
#             "To create confusion among buyers"
#         ]
#     },
#     {
#         "question": "What defines competition-based pricing?",
#         "options": [
#             "Setting prices based on competitors' strategies and prices",
#             "Ignoring competitor pricing completely",
#             "Choosing prices randomly",
#             "Always charging below market average"
#         ]
#     },
#     {
#         "question": "What is market-skimming pricing?",
#         "options": [
#             "Setting high initial prices to skim revenue from the market",
#             "Undercutting competitors to gain share",
#             "Offering freemium products",
#             "Bundling multiple products"
#         ]
#     },
#     {
#         "question": "What is the goal of penetration pricing?",
#         "options": [
#             "To attract many buyers and gain market share",
#             "To maximize short-term profits",
#             "To eliminate premium brands",
#             "To increase product quality"
#         ]
#     },
#     {
#         "question": "Which strategy involves pricing optional accessories separately?",
#         "options": [
#             "Optional-product pricing",
#             "Captive-product pricing",
#             "Bundle pricing",
#             "Psychological pricing"
#         ]
#     },
#     {
#         "question": "What is 'captive product pricing'?",
#         "options": [
#             "Pricing products that must be used with a main product",
#             "Offering core products for free",
#             "Charging one price for a product bundle",
#             "Giving away accessories"
#         ]
#     },
#     {
#         "question": "What is the purpose of bundle pricing?",
#         "options": [
#             "To offer several products at a reduced price",
#             "To sell single items only",
#             "To increase the price of core products",
#             "To simplify supply chains"
#         ]
#     },
#     {
#         "question": "Which tactic involves setting prices like $9.99?",
#         "options": [
#             "Charm pricing",
#             "Reference pricing",
#             "Anchoring",
#             "Freemium pricing"
#         ]
#     },
#     {
#         "question": "What is price anchoring?",
#         "options": [
#             "Presenting a higher price to make a lower price seem more attractive",
#             "Offering flat pricing for all items",
#             "Setting a price below cost",
#             "Charging different prices for the same product"
#         ]
#     },
#     {
#         "question": "What is a freemium pricing model?",
#         "options": [
#             "Offering a basic version for free and charging for advanced features",
#             "Charging everyone the same",
#             "Providing products only by subscription",
#             "Using one-time payment only"
#         ]
#     },
#     {
#         "question": "Which is NOT part of the transaction revenue model?",
#         "options": [
#             "Pay-as-you-wish (PAYW)",
#             "Markup (cost-plus)",
#             "One-time fee",
#             "CAPEX pricing"
#         ]
#     },
#     {
#         "question": "What type of revenue model is based on subscriptions and recurring fees?",
#         "options": [
#             "Recurring revenue model",
#             "Transaction-based model",
#             "One-time fee model",
#             "Promotional model"
#         ]
#     },
#     {
#         "question": "Sales-led growth companies rely on:",
#         "options": [
#             "Personal engagement and negotiation by a sales team",
#             "Fully automated product funnels",
#             "Organic social media only",
#             "App store promotions only"
#         ]
#     },
#     {
#         "question": "Product-led growth companies focus on:",
#         "options": [
#             "Letting the product drive user acquisition and retention",
#             "Hiring more salespeople",
#             "Only advertising strategies",
#             "Increasing store coverage"
#         ]
#     },
#     {
#         "question": "What is the purpose of psychological pricing?",
#         "options": [
#             "To influence consumer perception through price cues",
#             "To calculate profit margins",
#             "To align with production cost",
#             "To follow inflation rates"
#         ]
#     },
#     {
#         "question": "Which of the following uses decoy pricing?",
#         "options": [
#             "Adding a less attractive option to make another option more appealing",
#             "Offering identical prices for all options",
#             "Bidding on ad slots",
#             "Using two-for-one promotions"
#         ]
#     },
#     {
#         "question": "What is threshold pricing?",
#         "options": [
#             "Setting prices just below round numbers like $100 or $500",
#             "Matching competitor discounts",
#             "Changing prices daily",
#             "Offering dynamic fees based on location"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_pricing = [
#     {
#         "question": "Price is the most flexible element of the marketing mix.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Value-based pricing starts with production costs.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "EDLP aims to offer consistent low prices with few discounts.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "In competition-based pricing, companies completely ignore competitors’ prices.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Tesla initially used a market-skimming pricing strategy.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Netflix and Disney used market penetration pricing.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Optional product pricing includes mandatory accessories.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Captive product pricing sets high prices for necessary complementary items.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Bundle pricing discourages customers from purchasing multiple items.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Charm pricing can make products seem more affordable.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Freemium pricing gives the full product away for free forever.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Recurring revenue models rely on regular payments.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Sales-led companies depend heavily on product design to drive conversions.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Product-led growth strategies are more common in SaaS companies.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Price anchoring is used to make other prices appear cheaper.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     }
# ]

# # Combine and display
# questions_pricing = questions_a_pricing + questions_b_pricing

# insert_questions_with_topic(questions_pricing, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_lesson6 = [
#     {
#         "question": "What is customer experience (CX)?",
#         "options": [
#             "The total of all contacts and interactions with a company over time",
#             "Only the experience of purchasing a product",
#             "The technical performance of a product",
#             "Support calls after purchase"
#         ]
#     },
#     {
#         "question": "Which of the following is NOT part of CX?",
#         "options": [
#             "Just customer service interactions",
#             "Website browsing",
#             "Product usage",
#             "Digital communication"
#         ]
#     },
#     {
#         "question": "What is the primary difference between customer service and CX?",
#         "options": [
#             "CX includes all interactions before, during, and after purchase",
#             "CX is only about solving problems",
#             "Customer service is broader than CX",
#             "There is no difference"
#         ]
#     },
#     {
#         "question": "In the Kano Model, what happens if basic needs are unmet?",
#         "options": [
#             "Customers are disappointed",
#             "Customers are delighted",
#             "No impact on customer satisfaction",
#             "Customers receive discounts"
#         ]
#     },
#     {
#         "question": "According to the Kano Model, which need increases satisfaction the more it is fulfilled?",
#         "options": [
#             "Performance needs",
#             "Basic needs",
#             "Delighters",
#             "Post-purchase needs"
#         ]
#     },
#     {
#         "question": "What are Delighters in the Kano Model?",
#         "options": [
#             "Unexpected features that surprise and delight the customer",
#             "Refunds and credits",
#             "Requirements defined in contracts",
#             "Technical product specifications"
#         ]
#     },
#     {
#         "question": "What is the value of investing in Delighters?",
#         "options": [
#             "They create memorable and differentiated experiences",
#             "They reduce costs significantly",
#             "They replace basic needs",
#             "They only benefit support teams"
#         ]
#     },
#     {
#         "question": "Which model breaks down CX into stages like Awareness to Loyalty?",
#         "options": [
#             "Customer Journey Mapping",
#             "SWOT Analysis",
#             "SERVQUAL",
#             "AIDA"
#         ]
#     },
#     {
#         "question": "What does Customer Journey Mapping analyze?",
#         "options": [
#             "Touchpoints, emotions, pain points, and opportunities",
#             "Financial costs of marketing",
#             "Pricing fluctuations",
#             "Team productivity metrics"
#         ]
#     },
#     {
#         "question": "Which CX model evaluates the gap between expectations and perceptions?",
#         "options": [
#             "SERVQUAL",
#             "Kano Model",
#             "NPS",
#             "CES"
#         ]
#     },
#     {
#         "question": "Which of these is NOT a SERVQUAL metric?",
#         "options": [
#             "Speed",
#             "Empathy",
#             "Reliability",
#             "Appearance"
#         ]
#     },
#     {
#         "question": "What does NPS stand for?",
#         "options": [
#             "Net Promoter Score",
#             "Net Purchase Survey",
#             "New Product Sales",
#             "National Pricing Strategy"
#         ]
#     },
#     {
#         "question": "What is the key question in NPS?",
#         "options": [
#             "How likely are you to recommend us to a friend?",
#             "What was your last purchase?",
#             "What is your income level?",
#             "How many visits have you made?"
#         ]
#     },
#     {
#         "question": "What does CSAT measure?",
#         "options": [
#             "Customer satisfaction with a specific interaction",
#             "Overall brand awareness",
#             "Employee feedback",
#             "Technical product specs"
#         ]
#     },
#     {
#         "question": "What does CES measure?",
#         "options": [
#             "The effort a customer makes to complete an action",
#             "Customer empathy levels",
#             "Average support call time",
#             "Sales conversion rate"
#         ]
#     },
#     {
#         "question": "Which CX tool is most useful for tracking emotional highs and lows?",
#         "options": [
#             "Customer Journey Mapping",
#             "Email surveys",
#             "Technical diagnostics",
#             "Sales data analytics"
#         ]
#     },
#     {
#         "question": "Which of these focuses on perceived vs. expected service?",
#         "options": [
#             "SERVQUAL",
#             "NPS",
#             "Kano Model",
#             "Market Segmentation"
#         ]
#     },
#     {
#         "question": "What does the Heineken 'Dilemma' campaign aim to demonstrate?",
#         "options": [
#             "CX impact through social and emotional engagement",
#             "Promoting beer sales",
#             "New packaging design",
#             "Customer complaints handling"
#         ]
#     },
#     {
#         "question": "What role does emotion play in customer experience?",
#         "options": [
#             "It helps form long-lasting memories and impressions",
#             "It lowers product price",
#             "It increases staff turnover",
#             "It shortens product lifecycle"
#         ]
#     },
#     {
#         "question": "Why is customer experience considered strategic?",
#         "options": [
#             "It impacts loyalty, reputation, and revenue",
#             "It only helps the sales team",
#             "It simplifies finance management",
#             "It’s the same as customer service"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_lesson6 = [
#     {
#         "question": "Customer experience includes all interactions before, during, and after purchase.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "In the Kano Model, delighters are unexpected features that increase satisfaction.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Customer service and CX are the exact same thing.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Customer Journey Mapping tracks emotions and pain points at each stage.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "The SERVQUAL model evaluates product design quality.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Reliability and responsiveness are two of the SERVQUAL dimensions.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "NPS asks how likely a customer is to recommend a company.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "CSAT measures overall company profitability.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "CES measures how much effort a customer expends.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "CX strategies are only relevant after the sale is completed.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Delighters often surprise the customer and enhance loyalty.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Heineken's campaign is an example of emotionally engaging CX.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Customer journey mapping can uncover opportunities for improvement.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "CX has no influence on customer loyalty.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Good CX can differentiate a brand from its competitors.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     }
# ]

# # Combine and display
# questions_lesson6 = questions_a_lesson6 + questions_b_lesson6

# insert_questions_with_topic(questions_lesson6, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_ch12 = [
#     {
#         "question": "What is a marketing channel?",
#         "options": [
#             "A set of organizations that make a product available to consumers",
#             "A television advertising program",
#             "An online social media campaign",
#             "A customer feedback tool"
#         ]
#     },
#     {
#         "question": "Why do producers use marketing channels?",
#         "options": [
#             "To bridge time, place, and possession gaps",
#             "To reduce product quality",
#             "To increase advertising costs",
#             "To avoid digital platforms"
#         ]
#     },
#     {
#         "question": "Which of the following is a function of a channel member?",
#         "options": [
#             "Negotiation",
#             "Product design",
#             "Data encryption",
#             "Packaging only"
#         ]
#     },
#     {
#         "question": "Which type of conflict occurs among members at the same level?",
#         "options": [
#             "Horizontal conflict",
#             "Vertical conflict",
#             "Territorial conflict",
#             "Internal conflict"
#         ]
#     },
#     {
#         "question": "What does a vertical marketing system (VMS) do?",
#         "options": [
#             "Coordinates channel members into a unified system",
#             "Encourages independent competition between members",
#             "Eliminates producers",
#             "Focuses only on digital sales"
#         ]
#     },
#     {
#         "question": "Tesla's company-owned stores represent which VMS type?",
#         "options": [
#             "Corporate VMS",
#             "Administered VMS",
#             "Contractual VMS",
#             "Franchise system"
#         ]
#     },
#     {
#         "question": "A franchise system is an example of which VMS?",
#         "options": [
#             "Contractual",
#             "Corporate",
#             "Horizontal",
#             "Direct"
#         ]
#     },
#     {
#         "question": "Which VMS relies on the size and power of one member?",
#         "options": [
#             "Administered VMS",
#             "Contractual VMS",
#             "Horizontal VMS",
#             "Decentralized VMS"
#         ]
#     },
#     {
#         "question": "What is a horizontal marketing system?",
#         "options": [
#             "Two or more companies at the same level join to pursue an opportunity",
#             "Vertical integration of distribution and retail",
#             "A top-down franchising model",
#             "A system for controlling channel conflict"
#         ]
#     },
#     {
#         "question": "What is an example of a multichannel distribution system?",
#         "options": [
#             "Selling through retail, direct-to-consumer, and online platforms",
#             "Exclusive distribution in a single store",
#             "Online sales only",
#             "Door-to-door sales"
#         ]
#     },
#     {
#         "question": "What is intensive distribution?",
#         "options": [
#             "Stocking products in as many outlets as possible",
#             "Selling through only one exclusive distributor",
#             "Using personal selling only",
#             "Advertising in regional papers"
#         ]
#     },
#     {
#         "question": "What is exclusive distribution?",
#         "options": [
#             "Limiting distribution to a few dealers",
#             "Selling through every possible outlet",
#             "Creating direct competition",
#             "Targeting budget customers"
#         ]
#     },
#     {
#         "question": "What does selective distribution do?",
#         "options": [
#             "Uses only selected intermediaries meeting certain criteria",
#             "Excludes all intermediaries",
#             "Allows all stores to sell the product",
#             "Depends solely on digital sales"
#         ]
#     },
#     {
#         "question": "What must producers and intermediaries agree upon?",
#         "options": [
#             "Price policies and service terms",
#             "Company uniforms",
#             "Employee benefits",
#             "Software tools"
#         ]
#     },
#     {
#         "question": "What does 'exclusive dealing' involve?",
#         "options": [
#             "Requiring a dealer not to sell competitors’ products",
#             "Allowing all stores to carry any product",
#             "Sharing territory between competitors",
#             "Selling only to government agencies"
#         ]
#     },
#     {
#         "question": "What are tying agreements?",
#         "options": [
#             "Forcing dealers to buy a whole product line",
#             "Setting fixed price limits",
#             "Agreeing to joint advertising",
#             "Blocking territorial competition"
#         ]
#     },
#     {
#         "question": "What is a flow in a marketing channel?",
#         "options": [
#             "Movement of products, ownership, payments, and promotion",
#             "Only inventory storage",
#             "Store layout planning",
#             "Employee training processes"
#         ]
#     },
#     {
#         "question": "Who typically leads an administered VMS?",
#         "options": [
#             "The most powerful channel member",
#             "The customer",
#             "The advertising team",
#             "Local government"
#         ]
#     },
#     {
#         "question": "What does channel conflict refer to?",
#         "options": [
#             "Disagreement among members over goals and roles",
#             "Customer complaints",
#             "Pricing inflation",
#             "Shipment delays"
#         ]
#     },
#     {
#         "question": "What is one advantage of a multichannel distribution system?",
#         "options": [
#             "Reaching diverse customer segments",
#             "Cutting product features",
#             "Avoiding logistics partners",
#             "Reducing service quality"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_ch12 = [
#     {
#         "question": "Marketing channels help make products available to consumers.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Channel members may handle promotion, matching, and risk-taking.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Vertical conflict occurs between members at the same level.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "In a corporate VMS, all stages are owned by one entity.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Franchising is an example of a contractual VMS.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Horizontal marketing systems involve one company controlling all steps.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "A multichannel system uses only digital platforms.",
#         "options": [
#             "FALSE",
#             "TRUE"
#         ]
#     },
#     {
#         "question": "Selective distribution uses only resellers who meet certain criteria.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Exclusive dealing prevents retailers from carrying competitors’ products.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     },
#     {
#         "question": "Channel design decisions include choosing the number of intermediaries.",
#         "options": [
#             "TRUE",
#             "FALSE"
#         ]
#     }
# ]

# # Combine and display
# questions_ch12 = questions_a_ch12 + questions_b_ch12

# insert_questions_with_topic(questions_ch12, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_pricing2 = [
#     {
#         "question": "What is price in marketing?",
#         "options": [
#             "The amount of money charged or the sum of values exchanged for a product",
#             "The cost of producing a product",
#             "The tax added to a product",
#             "The average industry price"
#         ]
#     },
#     {
#         "question": "Which pricing strategy starts with customer value perceptions?",
#         "options": [
#             "Value-based pricing",
#             "Cost-based pricing",
#             "Competition-based pricing",
#             "Psychological pricing"
#         ]
#     },
#     {
#         "question": "What is Every Day Low Pricing (EDLP)?",
#         "options": [
#             "Charging a constant low price with few or no temporary discounts",
#             "Using high-low pricing with frequent promotions",
#             "Selling at high initial prices only",
#             "A strategy used only by luxury brands"
#         ]
#     },
#     {
#         "question": "Which pricing method is used by Porsche Drive?",
#         "options": [
#             "Value-added pricing",
#             "Penetration pricing",
#             "EDLP",
#             "Cost-plus pricing"
#         ]
#     },
#     {
#         "question": "Which strategy focuses on matching or beating competitor pricing?",
#         "options": [
#             "Competition-based pricing",
#             "Value-based pricing",
#             "Cost-plus pricing",
#             "Freemium pricing"
#         ]
#     },
#     {
#         "question": "What is market-skimming pricing?",
#         "options": [
#             "Setting high initial prices to target affluent customers",
#             "Launching with discounts to attract volume",
#             "Giving away products for free",
#             "Penalizing late payments"
#         ]
#     },
#     {
#         "question": "What is market-penetration pricing?",
#         "options": [
#             "Setting low prices to gain market share quickly",
#             "Launching at high price to skim revenue",
#             "Using psychological pricing cues",
#             "Avoiding digital platforms"
#         ]
#     },
#     {
#         "question": "Which product pricing strategy applies to accessories?",
#         "options": [
#             "Optional-product pricing",
#             "Bundle pricing",
#             "Captive pricing",
#             "Line pricing"
#         ]
#     },
#     {
#         "question": "Which pricing strategy sells printers cheap and ink cartridges at high markup?",
#         "options": [
#             "Captive-product pricing",
#             "Optional-product pricing",
#             "Line pricing",
#             "Threshold pricing"
#         ]
#     },
#     {
#         "question": "What does bundle pricing do?",
#         "options": [
#             "Combines several products at a reduced price",
#             "Charges one price for each item separately",
#             "Avoids discounts",
#             "Prices optional products higher"
#         ]
#     },
#     {
#         "question": "What is charm pricing?",
#         "options": [
#             "Pricing just under round numbers, like $9.99",
#             "Offering a luxury-only tier",
#             "Providing customer coupons",
#             "Increasing prices gradually"
#         ]
#     },
#     {
#         "question": "What is price anchoring?",
#         "options": [
#             "Using a high reference price to make another option seem cheaper",
#             "Selling products above competitors",
#             "Giving away decoy products",
#             "Showing hidden fees last"
#         ]
#     },
#     {
#         "question": "What is decoy pricing?",
#         "options": [
#             "Adding a worse offer to make another one more attractive",
#             "Offering the same product at three different prices",
#             "Using subscription bundles",
#             "Offering different prices based on age"
#         ]
#     },
#     {
#         "question": "What is freemium pricing?",
#         "options": [
#             "Offering basic features for free and charging for advanced ones",
#             "Giving everything away forever",
#             "Charging monthly without free access",
#             "Avoiding competition"
#         ]
#     },
#     {
#         "question": "What is a transaction revenue model?",
#         "options": [
#             "Revenue from markups or one-time fees",
#             "Recurring subscription-based income",
#             "Advertising-based revenue",
#             "Free trial and donation only"
#         ]
#     },
#     {
#         "question": "Which model generates revenue via subscriptions or licensing?",
#         "options": [
#             "Recurring revenue model",
#             "Freemium model",
#             "Transaction-based model",
#             "Threshold pricing model"
#         ]
#     },
#     {
#         "question": "What is a sales-led growth company?",
#         "options": [
#             "One that relies on direct engagement via sales teams",
#             "A brand using only SEO",
#             "A business with no sales department",
#             "A fully automated e-commerce brand"
#         ]
#     },
#     {
#         "question": "Product-led growth companies rely on:",
#         "options": [
#             "The product itself to drive acquisition and retention",
#             "Door-to-door sales",
#             "Sponsorships only",
#             "Retail store promotions"
#         ]
#     },
#     {
#         "question": "What is threshold pricing?",
#         "options": [
#             "Keeping prices just below a psychological number like $100",
#             "Setting all prices above market value",
#             "Allowing customers to set prices",
#             "Using discounts randomly"
#         ]
#     },
#     {
#         "question": "Which quote describes freemium strategy?",
#         "options": [
#             "\"If you’re not paying for it, you’re the product being sold\"",
#             "\"Buy one, get one free\"",
#             "\"All pricing is emotional\"",
#             "\"Low cost, high quality\""
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_pricing2 = [
#     {
#         "question": "Value-based pricing begins with the customer’s perception of value.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "EDLP avoids frequent price promotions.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "Market penetration pricing is used to enter markets quickly with low prices.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "Captive product pricing typically includes razor blades and printer ink.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "Bundle pricing is used to raise prices for basic items.",
#         "options": [
#             "FALSE", "TRUE"
#         ]
#     },
#     {
#         "question": "Charm pricing makes prices appear cheaper than they actually are.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "Freemium models offer full features for free permanently.",
#         "options": [
#             "FALSE", "TRUE"
#         ]
#     },
#     {
#         "question": "Sales-led companies rely on personal engagement and negotiation.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "Price anchoring uses a high price to make lower prices look better.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "Recurring revenue models include periodic licensing and usage fees.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     }
# ]

# # Combine and display
# questions_pricing2 = questions_a_pricing2 + questions_b_pricing2

# insert_questions_with_topic(questions_pricing2, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_ch7_mini = [
#     {
#         "question": "What is the first step in customer value–driven marketing strategy?",
#         "options": [
#             "Segmenting the market",
#             "Setting the price",
#             "Creating a perception map",
#             "Launching a product"
#         ]
#     },
#     {
#         "question": "Which segmentation base divides markets by personality and lifestyle?",
#         "options": [
#             "Psychographic segmentation",
#             "Demographic segmentation",
#             "Behavioral segmentation",
#             "Geographic segmentation"
#         ]
#     },
#     {
#         "question": "Which targeting strategy serves several segments with separate offers?",
#         "options": [
#             "Differentiated marketing",
#             "Mass marketing",
#             "Niche marketing",
#             "One-to-one marketing"
#         ]
#     },
#     {
#         "question": "What does a positioning map show?",
#         "options": [
#             "Consumer perceptions of brands on key attributes",
#             "Product cost breakdown",
#             "Sales growth by quarter",
#             "Competitor pricing errors"
#         ]
#     },
#     {
#         "question": "What should a competitive advantage be?",
#         "options": [
#             "Important, distinctive, communicable, and profitable",
#             "Cheap, common, fast, and temporary",
#             "Vague and complicated",
#             "Hidden and technical"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_ch7_mini = [
#     {
#         "question": "Behavioral segmentation includes user status and usage rate.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "Micromarketing targets broad, mass markets.",
#         "options": [
#             "FALSE", "TRUE"
#         ]
#     },
#     {
#         "question": "Positioning is how consumers define a product in their minds.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "A value proposition explains why a brand is more expensive.",
#         "options": [
#             "FALSE", "TRUE"
#         ]
#     },
#     {
#         "question": "Individual marketing is also called one-to-one marketing.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     }
# ]

# # Combine and display
# questions_ch7_mini = questions_a_ch7_mini + questions_b_ch7_mini

# insert_questions_with_topic(questions_ch7_mini, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_ch7_mini = [
#     {
#         "question": "What is the first step in customer value–driven marketing strategy?",
#         "options": [
#             "Segmenting the market",
#             "Setting the price",
#             "Creating a perception map",
#             "Launching a product"
#         ]
#     },
#     {
#         "question": "Which segmentation base divides markets by personality and lifestyle?",
#         "options": [
#             "Psychographic segmentation",
#             "Demographic segmentation",
#             "Behavioral segmentation",
#             "Geographic segmentation"
#         ]
#     },
#     {
#         "question": "Which targeting strategy serves several segments with separate offers?",
#         "options": [
#             "Differentiated marketing",
#             "Mass marketing",
#             "Niche marketing",
#             "One-to-one marketing"
#         ]
#     },
#     {
#         "question": "What does a positioning map show?",
#         "options": [
#             "Consumer perceptions of brands on key attributes",
#             "Product cost breakdown",
#             "Sales growth by quarter",
#             "Competitor pricing errors"
#         ]
#     },
#     {
#         "question": "What should a competitive advantage be?",
#         "options": [
#             "Important, distinctive, communicable, and profitable",
#             "Cheap, common, fast, and temporary",
#             "Vague and complicated",
#             "Hidden and technical"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_ch7_mini = [
#     {
#         "question": "Behavioral segmentation includes user status and usage rate.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "Micromarketing targets broad, mass markets.",
#         "options": [
#             "FALSE", "TRUE"
#         ]
#     },
#     {
#         "question": "Positioning is how consumers define a product in their minds.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "A value proposition explains why a brand is more expensive.",
#         "options": [
#             "FALSE", "TRUE"
#         ]
#     },
#     {
#         "question": "Individual marketing is also called one-to-one marketing.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     }
# ]

# # Combine and display
# questions_ch7_mini = questions_a_ch7_mini + questions_b_ch7_mini

# insert_questions_with_topic(questions_ch7_mini, "marketing")

# %%
# # Type A (Multiple Choice) Questions – correct answer always first
# questions_a_ch1_mini = [
#     {
#         "question": "What is the main focus of marketing according to the modern definition?",
#         "options": [
#             "Creating customer value and building strong relationships",
#             "Maximizing short-term profits",
#             "Advertising and promotion",
#             "Selling as many products as possible"
#         ]
#     },
#     {
#         "question": "In marketing, what is a 'need'?",
#         "options": [
#             "A state of felt deprivation",
#             "A desire based on culture",
#             "A product feature",
#             "An advertising message"
#         ]
#     },
#     {
#         "question": "What is 'marketing myopia'?",
#         "options": [
#             "Focusing too much on the product rather than customer needs",
#             "Ignoring advertising effectiveness",
#             "Overspending on research",
#             "Selling in limited locations"
#         ]
#     },
#     {
#         "question": "What is a value proposition?",
#         "options": [
#             "The set of benefits a brand promises to deliver",
#             "The pricing formula used in marketing",
#             "A type of packaging strategy",
#             "A segment of the target market"
#         ]
#     },
#     {
#         "question": "Which concept considers customer needs, company goals, and societal well-being?",
#         "options": [
#             "Societal marketing concept",
#             "Production concept",
#             "Selling concept",
#             "Segmentation model"
#         ]
#     }
# ]

# # Type B (True/False) Questions
# questions_b_ch1_mini = [
#     {
#         "question": "The marketing mix includes Product, Price, Place, and Promotion.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "Customer satisfaction occurs when perceived performance matches or exceeds expectations.",
#         "options": [
#             "TRUE", "FALSE"
#         ]
#     },
#     {
#         "question": "The selling concept begins with customer needs and ends with customer satisfaction.",
#         "options": [
#             "FALSE", "TRUE"
#         ]
#     },
#     {
#         "question": "Customer relationship management only applies after the purchase is complete.",
#         "options": [
#             "FALSE", "TRUE"
#         ]
#     },
#     {
#         "question": "In a modern marketing system, only the company and customer are involved.",
#         "options": [
#             "FALSE", "TRUE"
#         ]
#     }
# ]

# # Combine and display
# questions_ch1_mini = questions_a_ch1_mini + questions_b_ch1_mini

# insert_questions_with_topic(questions_ch1_mini, "marketing")

# %%
# # Creating 15 challenging multiple-choice and 10 challenging true/false questions
# questions_hard_mc = [
#     {
#         "question": "In the SERVQUAL model, which dimension evaluates how well a company delivers on its promises?",
#         "options": [
#             "Reliability",
#             "Empathy",
#             "Appearance",
#             "Responsiveness"
#         ]
#     },
#     {
#         "question": "Which pricing strategy involves offering a low price to attract a broad market and deter competitors?",
#         "options": [
#             "Market-penetration pricing",
#             "Skimming pricing",
#             "Value-added pricing",
#             "High-low pricing"
#         ]
#     },
#     {
#         "question": "Which type of marketing system involves coordination through the size and power of one dominant channel member?",
#         "options": [
#             "Administered Vertical Marketing System",
#             "Corporate VMS",
#             "Contractual VMS",
#             "Horizontal Marketing System"
#         ]
#     },
#     {
#         "question": "In the context of digital personas, which factor is most useful in customizing content delivery?",
#         "options": [
#             "Platform preferences",
#             "Product pricing",
#             "Supplier contracts",
#             "Employee schedules"
#         ]
#     },
#     {
#         "question": "What is the primary advantage of a multichannel distribution system?",
#         "options": [
#             "Reaching diverse customer segments effectively",
#             "Lower production costs",
#             "Reduced need for promotion",
#             "Better packaging efficiency"
#         ]
#     },
#     {
#         "question": "Which CX measurement tool evaluates customer effort during interactions?",
#         "options": [
#             "CES (Customer Effort Score)",
#             "CSAT",
#             "NPS",
#             "SERVQUAL"
#         ]
#     },
#     {
#         "question": "What strategy did Tesla initially use to price its electric vehicles?",
#         "options": [
#             "Market-skimming pricing",
#             "Freemium pricing",
#             "Value-added pricing",
#             "Psychological pricing"
#         ]
#     },
#     {
#         "question": "Which demographic group is described as tech-savvy and blending online and offline worlds?",
#         "options": [
#             "Generation Z",
#             "Generation X",
#             "Millennials",
#             "Baby Boomers"
#         ]
#     },
#     {
#         "question": "Which pricing method includes charm pricing, threshold pricing, and decoy pricing?",
#         "options": [
#             "Psychological pricing",
#             "Cost-based pricing",
#             "Competitive pricing",
#             "Dynamic pricing"
#         ]
#     },
#     {
#         "question": "What is the key insight of the 'Crossing the Chasm' model in innovation adoption?",
#         "options": [
#             "Many products fail to transition from early adopters to the mainstream market",
#             "Most innovations succeed after early adoption",
#             "Early adopters are highly price-sensitive",
#             "Innovators rely solely on peer reviews"
#         ]
#     },
#     {
#         "question": "In the Kano model, what type of feature greatly enhances satisfaction if present but doesn't disappoint if missing?",
#         "options": [
#             "Delighters",
#             "Performance needs",
#             "Basic needs",
#             "Warranty features"
#         ]
#     },
#     {
#         "question": "What pricing approach is based on consumers' perceived value instead of the seller’s cost?",
#         "options": [
#             "Value-based pricing",
#             "Cost-plus pricing",
#             "Markup pricing",
#             "Competitive parity pricing"
#         ]
#     },
#     {
#         "question": "What term describes a system where two or more companies at the same level join to exploit a new opportunity?",
#         "options": [
#             "Horizontal marketing system",
#             "Vertical integration",
#             "Franchise network",
#             "Multichannel collaboration"
#         ]
#     },
#     {
#         "question": "What does CSAT specifically measure?",
#         "options": [
#             "Customer satisfaction with a specific interaction or transaction",
#             "Overall brand loyalty",
#             "Future buying intention",
#             "Sales growth"
#         ]
#     },
#     {
#         "question": "What type of revenue model includes licensing fees and usage-based charges?",
#         "options": [
#             "Recurring revenue model",
#             "Transactional model",
#             "One-time fee model",
#             "Barter model"
#         ]
#     }
# ]

# questions_hard_tf = [
#     {
#         "question": "Customer experience includes interactions before, during, and after the purchase.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Exclusive distribution means selling products through all possible outlets.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Freemium pricing gives basic access for free while monetizing premium users.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "A value proposition focuses only on product features and not customer benefits.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "The CSAT metric is best for evaluating overall brand perception.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Contractual VMS includes franchise systems and agreements.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Charm pricing refers to rounding prices up to the nearest whole number.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Administered VMSs rely on formal ownership of each channel member.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Shona Warrington values sustainable packaging and eco-conscious branding.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Heineken's 'Dilemma' campaign aimed to highlight competitive pricing advantages.",
#         "options": ["FALSE", "TRUE"]
#     }
# ]

# # Combine and display
# questions_hard_total = questions_hard_mc + questions_hard_tf

# insert_questions_with_topic(questions_hard_total, "marketing")

# %%
# # Additional 15 Multiple Choice and 10 True/False Hard Questions

# questions_hard2_mc = [
#     {
#         "question": "What does the NPS metric primarily measure?",
#         "options": [
#             "Customer likelihood to recommend a brand",
#             "Net pricing strategy effectiveness",
#             "Product return rates",
#             "Service delivery speed"
#         ]
#     },
#     {
#         "question": "Which distribution strategy is best suited for luxury brands?",
#         "options": [
#             "Exclusive distribution",
#             "Intensive distribution",
#             "Multichannel distribution",
#             "Indirect distribution"
#         ]
#     },
#     {
#         "question": "In the Bass Diffusion Model, 'p' represents which group?",
#         "options": [
#             "Innovators",
#             "Imitators",
#             "Late adopters",
#             "Non-adopters"
#         ]
#     },
#     {
#         "question": "Which persona factor is critical for targeting behaviorally segmented audiences?",
#         "options": [
#             "Purchase history",
#             "Birthplace",
#             "Company size",
#             "City elevation"
#         ]
#     },
#     {
#         "question": "What does the term 'marketing myopia' warn against?",
#         "options": [
#             "Focusing too much on the product rather than customer needs",
#             "Selling below cost",
#             "Using too many marketing channels",
#             "Hiring only creative marketers"
#         ]
#     },
#     {
#         "question": "Which of the following is an example of a delighter in the Kano model?",
#         "options": [
#             "Free surprise upgrade in hotel",
#             "On-time delivery",
#             "Product functionality",
#             "Basic safety features"
#         ]
#     },
#     {
#         "question": "A/B testing is primarily used to:",
#         "options": [
#             "Compare two versions of a campaign for effectiveness",
#             "Recruit influencers",
#             "Manage product inventory",
#             "Calculate unit costs"
#         ]
#     },
#     {
#         "question": "What is the goal of the societal marketing concept?",
#         "options": [
#             "Deliver value to customers while enhancing societal well-being",
#             "Maximize short-term profit only",
#             "Focus on product features",
#             "Ignore environmental concerns"
#         ]
#     },
#     {
#         "question": "Which of the following best defines 'decoy pricing'?",
#         "options": [
#             "Introducing a third, less attractive option to nudge choice",
#             "Adding hidden fees",
#             "Offering 3-for-1 deals",
#             "Adjusting prices based on customer income"
#         ]
#     },
#     {
#         "question": "Which CX tool maps all customer touchpoints and emotions?",
#         "options": [
#             "Customer Journey Mapping",
#             "RFM Analysis",
#             "Net Value Index",
#             "Marketing Mix Model"
#         ]
#     },
#     {
#         "question": "What kind of segmentation divides the market by usage occasions?",
#         "options": [
#             "Behavioral segmentation",
#             "Psychographic segmentation",
#             "Demographic segmentation",
#             "Firmographic segmentation"
#         ]
#     },
#     {
#         "question": "Which pricing tactic is used when a company sells a high-quality printer cheaply but charges more for ink?",
#         "options": [
#             "Captive-product pricing",
#             "Optional-product pricing",
#             "Cost-plus pricing",
#             "Price anchoring"
#         ]
#     },
#     {
#         "question": "What is the primary reason for using selective distribution?",
#         "options": [
#             "Control over reseller image and quality",
#             "Maximum availability",
#             "Minimal advertising costs",
#             "To eliminate channel members"
#         ]
#     },
#     {
#         "question": "What does the CES (Customer Effort Score) metric best capture?",
#         "options": [
#             "Ease of completing a customer task",
#             "Brand loyalty over time",
#             "Customer satisfaction with design",
#             "Sales growth from new users"
#         ]
#     },
#     {
#         "question": "Which innovation type modifies existing offerings to meet evolving needs?",
#         "options": [
#             "Incremental innovation",
#             "Radical innovation",
#             "Disruptive innovation",
#             "Zero-based innovation"
#         ]
#     }
# ]

# questions_hard2_tf = [
#     {
#         "question": "Innovators typically adopt new products before early adopters.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "A Customer Persona includes demographics, pain points, and goals.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "The goal of value-based pricing is to recover production cost.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Customer experience does not impact brand loyalty significantly.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Micromarketing aims to tailor products to individual customer needs.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "In selective distribution, the product is sold in every available outlet.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "In the customer journey, pain points refer to areas of emotional delight.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "In market-skimming pricing, companies start with high prices to maximize profits early.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Value propositions explain how a product’s value is better than competitors.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "A horizontal conflict occurs between companies at different levels of the channel.",
#         "options": ["FALSE", "TRUE"]
#     }
# ]

# # Combine and display
# questions_hard2_total = questions_hard2_mc + questions_hard2_tf

# insert_questions_with_topic(questions_hard2_total, "marketing")

# %%
# # Another set of 15 Multiple Choice and 10 True/False Questions

# questions_hard3_mc = [
#     {
#         "question": "Which channel function helps match product offerings with customer needs?",
#         "options": [
#             "Matching",
#             "Negotiating",
#             "Risk taking",
#             "Financing"
#         ]
#     },
#     {
#         "question": "What is a key feature of B2B buying behavior compared to B2C?",
#         "options": [
#             "B2B purchases often involve complex decision-making units",
#             "B2B purchases are always emotional",
#             "B2B customers never look for after-sale support",
#             "B2B products are mainly impulse purchases"
#         ]
#     },
#     {
#         "question": "In which stage of the product life cycle does competition typically peak?",
#         "options": [
#             "Maturity",
#             "Growth",
#             "Introduction",
#             "Decline"
#         ]
#     },
#     {
#         "question": "What does the value delivery network include?",
#         "options": [
#             "Company, suppliers, distributors, and customers",
#             "Sales department only",
#             "Suppliers only",
#             "Employees and managers only"
#         ]
#     },
#     {
#         "question": "Which type of pricing considers both cost and customer perception of value?",
#         "options": [
#             "Value-based pricing",
#             "Cost-plus pricing",
#             "Freemium pricing",
#             "Optional product pricing"
#         ]
#     },
#     {
#         "question": "What does the acronym STP stand for in marketing?",
#         "options": [
#             "Segmentation, Targeting, Positioning",
#             "Strategy, Tactics, Pricing",
#             "Sales, Tools, Performance",
#             "Standard, Trial, Product"
#         ]
#     },
#     {
#         "question": "Which segmentation base groups customers based on benefits sought?",
#         "options": [
#             "Behavioral segmentation",
#             "Geographic segmentation",
#             "Demographic segmentation",
#             "Occasional segmentation"
#         ]
#     },
#     {
#         "question": "Which concept focuses on producing goods efficiently and at low cost?",
#         "options": [
#             "Production concept",
#             "Selling concept",
#             "Societal marketing concept",
#             "Marketing concept"
#         ]
#     },
#     {
#         "question": "Which method collects data by watching customers interact with products?",
#         "options": [
#             "Observational research",
#             "Ethnographic surveys",
#             "Focus group interviews",
#             "Experimental design"
#         ]
#     },
#     {
#         "question": "Which concept starts with the market and focuses on customer needs?",
#         "options": [
#             "Marketing concept",
#             "Production concept",
#             "Selling concept",
#             "Technology concept"
#         ]
#     },
#     {
#         "question": "What is a persona in marketing?",
#         "options": [
#             "A fictional profile representing a target customer",
#             "A company’s spokesperson",
#             "The CEO’s marketing summary",
#             "A product launch strategy"
#         ]
#     },
#     {
#         "question": "What is a key advantage of digital marketing for sellers?",
#         "options": [
#             "Precise targeting and measurable results",
#             "Faster logistics systems",
#             "Cheaper warehouses",
#             "Less customer involvement"
#         ]
#     },
#     {
#         "question": "Which strategy combines multiple online and offline touchpoints?",
#         "options": [
#             "Omnichannel strategy",
#             "Push strategy",
#             "Direct channel strategy",
#             "Market-skimming strategy"
#         ]
#     },
#     {
#         "question": "What does the Heineken 'Dilemma' campaign primarily demonstrate?",
#         "options": [
#             "Emotion and social interaction in branding",
#             "Pricing strategy for beverages",
#             "Customer acquisition via coupons",
#             "New market expansion"
#         ]
#     },
#     {
#         "question": "What does NPS categorize customers into?",
#         "options": [
#             "Promoters, Passives, Detractors",
#             "Buyers, Browsers, Abandoners",
#             "Loyalists, Critics, Reviewers",
#             "Trial users, Upgraders, Downgraders"
#         ]
#     }
# ]

# questions_hard3_tf = [
#     {
#         "question": "Market segmentation allows companies to target the same message to everyone.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Product-led growth relies on the product to attract and retain users.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Contractual VMS involves a common ownership of the production-distribution process.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Derived demand in B2B means business demand is driven by consumer demand.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Ethnographic research typically occurs in the lab.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "In behavioral segmentation, loyalty status is a key variable.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Pricing is considered one of the most flexible elements of the marketing mix.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Sales-led growth depends mainly on customer self-service interfaces.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Charm pricing uses prices like $9.99 to appear cheaper.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "The customer journey includes only the purchase phase.",
#         "options": ["FALSE", "TRUE"]
#     }
# ]

# # Combine and display
# questions_hard3_total = questions_hard3_mc + questions_hard3_tf

# insert_questions_with_topic(questions_hard3_total, "marketing")

# %%
# # Another set of 15 Multiple Choice and 10 True/False Questions (Set 4)

# questions_hard4_mc = [
#     {
#         "question": "Which metric is best suited to gauge loyalty through word-of-mouth behavior?",
#         "options": [
#             "Net Promoter Score (NPS)",
#             "Customer Satisfaction (CSAT)",
#             "Customer Effort Score (CES)",
#             "Return on Investment (ROI)"
#         ]
#     },
#     {
#         "question": "What is a major characteristic of psychographic segmentation?",
#         "options": [
#             "Based on lifestyle and personality traits",
#             "Based on customer income only",
#             "Defined by zip codes",
#             "Grouped by purchase frequency only"
#         ]
#     },
#     {
#         "question": "In a contractual VMS, coordination is achieved through:",
#         "options": [
#             "Legal agreements and contracts",
#             "Ownership of all levels",
#             "Company hierarchy",
#             "Conflict negotiation committees"
#         ]
#     },
#     {
#         "question": "The introduction stage in the product life cycle is usually marked by:",
#         "options": [
#             "High marketing costs and slow sales",
#             "High profitability and minimal promotion",
#             "Rapid sales and low competition",
#             "Wide product acceptance"
#         ]
#     },
#     {
#         "question": "Which digital marketing strategy allows ads to be automatically bought and placed?",
#         "options": [
#             "Programmatic advertising",
#             "Keyword optimization",
#             "Native ad placement",
#             "Manual bidding"
#         ]
#     },
#     {
#         "question": "What is the main goal of using a persona in marketing?",
#         "options": [
#             "To humanize and better understand target segments",
#             "To build finance reports",
#             "To eliminate competitor advantage",
#             "To set profit margins"
#         ]
#     },
#     {
#         "question": "Which customer group is least likely to adopt a new product?",
#         "options": [
#             "Laggards",
#             "Early majority",
#             "Early adopters",
#             "Innovators"
#         ]
#     },
#     {
#         "question": "Which is a challenge of using multichannel distribution?",
#         "options": [
#             "Channel conflict and control complexity",
#             "Single channel reliance",
#             "Reduced consumer awareness",
#             "High product failure rates"
#         ]
#     },
#     {
#         "question": "Which research method is best for exploring deep emotional insights?",
#         "options": [
#             "Focus groups",
#             "Online survey",
#             "Click-through analysis",
#             "Point-of-sale monitoring"
#         ]
#     },
#     {
#         "question": "What defines straight rebuy behavior in B2B markets?",
#         "options": [
#             "Routine reorder without modification",
#             "Completely new supplier search",
#             "A major strategy shift",
#             "Multi-vendor contract signing"
#         ]
#     },
#     {
#         "question": "Which model highlights product attributes important to consumers?",
#         "options": [
#             "Perceptual positioning map",
#             "SWOT diagram",
#             "Gantt chart",
#             "Balanced scorecard"
#         ]
#     },
#     {
#         "question": "Which CX metric is most useful for understanding perceived service quality?",
#         "options": [
#             "SERVQUAL",
#             "CES",
#             "NPS",
#             "Share of Wallet"
#         ]
#     },
#     {
#         "question": "What is the purpose of tying agreements in channel design?",
#         "options": [
#             "Forcing the purchase of additional products",
#             "Opening direct competitors’ stock",
#             "Allowing dynamic pricing",
#             "Reducing customer churn"
#         ]
#     },
#     {
#         "question": "Which pricing strategy uses a high starting price for innovation?",
#         "options": [
#             "Market-skimming pricing",
#             "Cost-plus pricing",
#             "Value bundle pricing",
#             "Everyday low pricing"
#         ]
#     },
#     {
#         "question": "What is the first step in the marketing research process?",
#         "options": [
#             "Define the problem and objectives",
#             "Collect secondary data",
#             "Select a sampling method",
#             "Draft a customer persona"
#         ]
#     }
# ]

# questions_hard4_tf = [
#     {
#         "question": "Positioning refers to the way a product is defined by consumers on key attributes.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Selective distribution is suitable for convenience goods like snacks and gum.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Administered VMS coordinates production and distribution through shared ownership.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "The primary goal of CES is to evaluate the emotional tone of a service experience.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "In B2B, 'gatekeepers' control the flow of information in the buying process.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Digital personas help deliver personalized experiences at scale.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Crowdsourcing is a way to outsource production to suppliers abroad.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Psychographic segmentation uses attitudes, values, and lifestyle to group customers.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "A perceptual map always shows actual product prices.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "High-low pricing combines regular high prices with frequent discounts.",
#         "options": ["TRUE", "FALSE"]
#     }
# ]

# # Combine and display
# questions_hard4_total = questions_hard4_mc + questions_hard4_tf
# insert_questions_with_topic(questions_hard4_total, "marketing")

# %%
# # Another set of 15 Multiple Choice and 10 True/False Questions (Set 5)

# questions_hard5_mc = [
#     {
#         "question": "What is the purpose of a positioning statement?",
#         "options": [
#             "To define how a product should be perceived by the target market",
#             "To outline sales team responsibilities",
#             "To specify production scheduling",
#             "To determine advertising budget"
#         ]
#     },
#     {
#         "question": "What is an example of behavioral segmentation?",
#         "options": [
#             "Segmenting based on purchase occasion",
#             "Dividing by income level",
#             "Clustering by zip code",
#             "Using personality types"
#         ]
#     },
#     {
#         "question": "Which research method is most useful for determining cause-effect relationships?",
#         "options": [
#             "Experimental research",
#             "Focus groups",
#             "Ethnographic observation",
#             "Sentiment analysis"
#         ]
#     },
#     {
#         "question": "What is a key feature of a product-led growth strategy?",
#         "options": [
#             "Users experience product value before purchasing",
#             "Heavy reliance on paid media",
#             "Sales team leads all interactions",
#             "Emphasis on outbound marketing"
#         ]
#     },
#     {
#         "question": "What best defines the term 'market offering'?",
#         "options": [
#             "A combination of products, services, and experiences offered to a market",
#             "The process of determining pricing strategies",
#             "The placement of goods in physical retail",
#             "A report used to assess supply chain effectiveness"
#         ]
#     },
#     {
#         "question": "What does a customer journey map help visualize?",
#         "options": [
#             "All touchpoints a customer experiences with a brand",
#             "Team responsibilities within a firm",
#             "Sales forecast for a quarter",
#             "Marketing automation rules"
#         ]
#     },
#     {
#         "question": "Which is NOT a component of the marketing mix?",
#         "options": [
#             "Positioning",
#             "Product",
#             "Price",
#             "Promotion"
#         ]
#     },
#     {
#         "question": "Which pricing strategy is influenced primarily by consumer psychology?",
#         "options": [
#             "Psychological pricing",
#             "Cost-plus pricing",
#             "Freemium pricing",
#             "Optional-product pricing"
#         ]
#     },
#     {
#         "question": "What are promoters in the NPS model likely to do?",
#         "options": [
#             "Recommend the company to others",
#             "Avoid responding to surveys",
#             "Complain publicly about products",
#             "Request service cancellation"
#         ]
#     },
#     {
#         "question": "What is one benefit of digital marketing for buyers?",
#         "options": [
#             "24/7 convenience and rich comparison tools",
#             "Mandatory offline checkout",
#             "Higher in-store prices",
#             "Reduced personalization"
#         ]
#     },
#     {
#         "question": "Which marketing concept emphasizes sustainable long-term relationships?",
#         "options": [
#             "Societal marketing concept",
#             "Selling concept",
#             "Production concept",
#             "Product concept"
#         ]
#     },
#     {
#         "question": "Which of the following is a performance benefit of using customer personas?",
#         "options": [
#             "More relevant content and targeted messaging",
#             "Broader generic advertisements",
#             "Higher logistics costs",
#             "Larger organizational charts"
#         ]
#     },
#     {
#         "question": "What is one characteristic of late majority adopters?",
#         "options": [
#             "Skeptical and adopt only after most others have tried",
#             "The first to experiment with innovations",
#             "Invest heavily before launch",
#             "Often create and test prototypes"
#         ]
#     },
#     {
#         "question": "Which revenue model is based on one-time purchases?",
#         "options": [
#             "Transactional revenue model",
#             "Subscription model",
#             "Licensing model",
#             "Freemium-to-paid model"
#         ]
#     },
#     {
#         "question": "In channel management, what is a typical source of vertical conflict?",
#         "options": [
#             "Disagreements between different levels like manufacturer and retailer",
#             "Retailers within the same city competing",
#             "Customer refund requests",
#             "Shortage of logistics providers"
#         ]
#     }
# ]

# questions_hard5_tf = [
#     {
#         "question": "A value proposition is the same as a slogan.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Customer engagement marketing aims to make brands a meaningful part of consumer conversations.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Marketing is only necessary in the final phase of product development.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "The production concept focuses primarily on availability and affordability.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Straight rebuy involves evaluating many new suppliers each time.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Customer loyalty is unrelated to perceived value.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Marketing channels only cover physical distribution.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "High-involvement purchases often require extended decision-making processes.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Captive-product pricing applies to core products with necessary accessories.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "The growth stage of the product life cycle is typically marked by rapid acceptance.",
#         "options": ["TRUE", "FALSE"]
#     }
# ]

# # Combine and display
# questions_hard5_total = questions_hard5_mc + questions_hard5_tf
# # Insert the questions into the database
# insert_questions_with_topic(questions_hard5_total, "marketing")

# %%
# # Another set of 15 challenging multiple choice and 10 true/false questions (Set 6)

# questions_hard6_mc = [
#     {
#         "question": "Which innovation adoption group is critical for crossing the chasm to the mainstream market?",
#         "options": [
#             "Early majority",
#             "Innovators",
#             "Laggards",
#             "Late majority"
#         ]
#     },
#     {
#         "question": "Which marketing tool evaluates both product value and emotional connection?",
#         "options": [
#             "Brand equity model",
#             "Sales funnel",
#             "Conversion rate tracker",
#             "Inventory turnover"
#         ]
#     },
#     {
#         "question": "Which strategy focuses on offering tailored content for hyper-specific audiences?",
#         "options": [
#             "Micromarketing",
#             "Mass marketing",
#             "High-low pricing",
#             "Dynamic segmentation"
#         ]
#     },
#     {
#         "question": "Which aspect of the customer journey is most associated with reducing churn?",
#         "options": [
#             "Post-purchase support",
#             "Product launch ads",
#             "Price discounting",
#             "Checkout page UX"
#         ]
#     },
#     {
#         "question": "Which pricing strategy can artificially inflate perceived value using a higher reference point?",
#         "options": [
#             "Anchoring",
#             "Penetration pricing",
#             "Dynamic pricing",
#             "Geographic pricing"
#         ]
#     },
#     {
#         "question": "What role does the 'gatekeeper' play in B2B buying behavior?",
#         "options": [
#             "Controls the flow of information to others in the buying center",
#             "Signs the purchase contract",
#             "Conducts the final price negotiation",
#             "Delivers post-sale customer support"
#         ]
#     },
#     {
#         "question": "Which of the following is a potential risk of omnichannel marketing?",
#         "options": [
#             "Inconsistent customer experience across touchpoints",
#             "Improved customer data visibility",
#             "High response rates",
#             "Stronger brand equity"
#         ]
#     },
#     {
#         "question": "How does value-added pricing differentiate from cost-plus pricing?",
#         "options": [
#             "It enhances product value perception rather than focusing on cost markup",
#             "It guarantees a discount on all units sold",
#             "It is only used by luxury brands",
#             "It includes taxes in price calculation"
#         ]
#     },
#     {
#         "question": "What is the primary concern of the societal marketing concept?",
#         "options": [
#             "Balancing company profits, consumer needs, and societal welfare",
#             "Maximizing online ad conversions",
#             "Targeting competitor customers",
#             "Increasing budget allocations for social media"
#         ]
#     },
#     {
#         "question": "What is the main function of SERVQUAL in marketing research?",
#         "options": [
#             "Measuring gaps between customer expectations and perceptions of service",
#             "Identifying the best distribution channels",
#             "Evaluating pricing elasticity",
#             "Calculating cost of customer acquisition"
#         ]
#     },
#     {
#         "question": "Which distribution strategy is most appropriate for products requiring extensive explanation or customization?",
#         "options": [
#             "Exclusive distribution",
#             "Intensive distribution",
#             "Digital-only distribution",
#             "Selective distribution"
#         ]
#     },
#     {
#         "question": "What is the key drawback of high-low pricing over EDLP?",
#         "options": [
#             "It can erode trust if promotions feel manipulative",
#             "It leads to lower sales volume always",
#             "It lacks any competitive value",
#             "It reduces production efficiency"
#         ]
#     },
#     {
#         "question": "What type of segmentation uses traits like leadership style or hobbies?",
#         "options": [
#             "Psychographic segmentation",
#             "Geographic segmentation",
#             "Behavioral segmentation",
#             "Usage segmentation"
#         ]
#     },
#     {
#         "question": "In digital campaigns, what is a key role of A/B testing?",
#         "options": [
#             "Comparing performance of two variations to improve effectiveness",
#             "Collecting customer contact data",
#             "Reducing operational costs",
#             "Setting ad pricing manually"
#         ]
#     },
#     {
#         "question": "Which metric is most appropriate for evaluating a user’s immediate experience with a product or service?",
#         "options": [
#             "CSAT (Customer Satisfaction Score)",
#             "NPS",
#             "CLV",
#             "Market share"
#         ]
#     }
# ]

# questions_hard6_tf = [
#     {
#         "question": "Captive-product pricing is commonly seen in the razor-and-blade business model.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Straight rebuy decisions involve the highest level of buyer involvement.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "A well-defined value proposition can help a company avoid marketing myopia.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "One benefit of omnichannel strategies is improved cross-device personalization.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "The growth stage in the product life cycle is typically unprofitable.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "SERVQUAL evaluates customer satisfaction across multiple service dimensions.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Product-led growth strategies are best suited for B2B hardware providers.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Horizontal marketing systems involve coordination among unrelated industries.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Behavioral segmentation can include benefits sought and loyalty status.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Net Promoter Score is used to predict long-term revenue growth.",
#         "options": ["TRUE", "FALSE"]
#     }
# ]

# # Combine and display
# questions_hard6_total = questions_hard6_mc + questions_hard6_tf
# insert_questions_with_topic(questions_hard6_total, "marketing")

# %%
# # Creating a 7th set of 15 hard multiple-choice and 10 true/false questions

# questions_hard7_mc = [
#     {
#         "question": "Which marketing strategy focuses on building long-term emotional connections with customers?",
#         "options": [
#             "Relationship marketing",
#             "Sales promotion",
#             "Transactional marketing",
#             "High-low pricing"
#         ]
#     },
#     {
#         "question": "Which of the following most directly affects the 'Place' element of the marketing mix?",
#         "options": [
#             "Distribution channels",
#             "Customer loyalty programs",
#             "Price bundling",
#             "Product warranties"
#         ]
#     },
#     {
#         "question": "In a horizontal marketing system, which of the following occurs?",
#         "options": [
#             "Two or more companies at the same level join to pursue a marketing opportunity",
#             "One company owns all levels of distribution",
#             "Manufacturers bypass wholesalers and retailers",
#             "Multiple franchises compete for space"
#         ]
#     },
#     {
#         "question": "Which term refers to making a product available where and when the customer wants it?",
#         "options": [
#             "Place utility",
#             "Form utility",
#             "Time segmentation",
#             "Channel conflict"
#         ]
#     },
#     {
#         "question": "Which analysis technique helps identify the profitability of individual customer segments?",
#         "options": [
#             "Customer Lifetime Value (CLV)",
#             "CSAT",
#             "CES",
#             "SWOT"
#         ]
#     },
#     {
#         "question": "Which digital marketing tactic is designed to recapture visitors who didn’t convert?",
#         "options": [
#             "Retargeting",
#             "Lead scoring",
#             "A/B testing",
#             "Affiliate marketing"
#         ]
#     },
#     {
#         "question": "What is a primary benefit of a customer insight team in a company?",
#         "options": [
#             "Understanding deep motivations behind customer behavior",
#             "Outsourcing content creation",
#             "Improving product logistics",
#             "Simplifying manufacturing"
#         ]
#     },
#     {
#         "question": "What is a major risk of using dynamic pricing?",
#         "options": [
#             "Customer backlash due to perceived unfairness",
#             "Supply chain delays",
#             "Channel saturation",
#             "Legal issues with product safety"
#         ]
#     },
#     {
#         "question": "Which type of buying situation requires extensive research and approval?",
#         "options": [
#             "New task",
#             "Modified rebuy",
#             "Straight rebuy",
#             "Automated order"
#         ]
#     },
#     {
#         "question": "Which term describes offering multiple related products at a single price?",
#         "options": [
#             "Bundle pricing",
#             "Line pricing",
#             "Value-based pricing",
#             "Dynamic pricing"
#         ]
#     },
#     {
#         "question": "What is the key difference between penetration and skimming pricing?",
#         "options": [
#             "Penetration aims for quick market entry; skimming targets early adopters with high prices",
#             "Skimming uses discounts to increase loyalty; penetration does not",
#             "Skimming is illegal in many markets",
#             "Penetration targets luxury segments only"
#         ]
#     },
#     {
#         "question": "Which concept states that the whole marketing system should deliver greater value than competitors?",
#         "options": [
#             "Competitive advantage",
#             "Core competence",
#             "Target marketing",
#             "Franchise synergy"
#         ]
#     },
#     {
#         "question": "Which segmentation method would most likely divide a market by brand loyalty?",
#         "options": [
#             "Behavioral segmentation",
#             "Psychographic segmentation",
#             "Geographic segmentation",
#             "Demographic segmentation"
#         ]
#     },
#     {
#         "question": "What is the role of a 'decider' in a B2B buying center?",
#         "options": [
#             "The person with final purchase authority",
#             "The supplier contacting manager",
#             "The finance controller",
#             "The user testing the product"
#         ]
#     },
#     {
#         "question": "Which strategy is designed to deliver consistent experiences across digital and physical channels?",
#         "options": [
#             "Omnichannel marketing",
#             "Niche marketing",
#             "Direct marketing",
#             "Channel skimming"
#         ]
#     }
# ]

# questions_hard7_tf = [
#     {
#         "question": "High-involvement products typically require more customer education and evaluation.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "In marketing, a 'segment' is a homogeneous group of customers with identical preferences.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "A gatekeeper in B2B often controls access to other decision-makers.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Early adopters are typically more conservative than the early majority.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Perceived value directly influences a customer's willingness to pay.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "SWOT analysis includes factors like customer lifetime value and pricing elasticity.",
#         "options": ["FALSE", "TRUE"]
#     },
#     {
#         "question": "Cross-selling is the practice of selling a different category of product to an existing customer.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Click-through rate (CTR) is a common KPI in digital display advertising.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Integrated marketing communication (IMC) seeks to unify all promotional tools and messages.",
#         "options": ["TRUE", "FALSE"]
#     },
#     {
#         "question": "Positioning maps help companies analyze supply chain logistics.",
#         "options": ["FALSE", "TRUE"]
#     }
# ]

# # Combine and display
# questions_hard7_total = questions_hard7_mc + questions_hard7_tf
# # Insert the questions into the database
# insert_questions_with_topic(questions_hard7_total, "marketing")

# %%
# # Create 7 Type C case analysis questions with a short paragraph and 4 sub-questions each
# case_type_c_questions = [
#     {
#         "question": "CASE STUDY: A new startup called 'EcoSip' produces biodegradable coffee cups. They want to enter the European market, which is saturated with eco-friendly packaging solutions. EcoSip's cups degrade in 10 days and cost 10% more than standard paper cups.",
#         "options": [
#             "What should EcoSip’s positioning strategy focus on?",
#             "Which marketing mix element should they prioritize to create market awareness?",
#             "What target market segment should they initially focus on?",
#             "Suggest one way EcoSip can differentiate from existing eco-packaging competitors."
#         ]
#     },
#     {
#         "question": "CASE STUDY: ‘FitBytes’ is a local health snack company entering the online subscription model. They plan to offer monthly boxes with high-protein snacks. Their competitors include major international health brands and meal kits.",
#         "options": [
#             "What digital marketing channel would be most effective for FitBytes’ launch?",
#             "How can they build customer loyalty in a subscription model?",
#             "Which STP strategy should FitBytes use to gain initial traction?",
#             "Suggest one pricing strategy FitBytes could adopt to attract first-time users."
#         ]
#     },
#     {
#         "question": "CASE STUDY: ‘StudySphere’ is a new mobile app offering AI-based flashcards and quizzes for students aged 16–24. The education market is crowded with apps like Quizlet, Anki, and Duolingo. StudySphere claims faster learning results based on user behavior analysis.",
#         "options": [
#             "What positioning approach should StudySphere take against existing competitors?",
#             "Which user acquisition channel should they prioritize for this demographic?",
#             "Which feature could support their product-led growth strategy?",
#             "Suggest one promotional offer for launch."
#         ]
#     },
#     {
#         "question": "CASE STUDY: ‘PureGlow’ is a new skincare brand targeting Gen Z and Millennials. Its products are vegan, cruelty-free, and made from recycled packaging. They want to compete with established beauty brands like Glossier and The Ordinary.",
#         "options": [
#             "What emotional message could PureGlow use to connect with Gen Z?",
#             "What influencer strategy could boost brand credibility?",
#             "Which aspect of the product mix should PureGlow emphasize?",
#             "How can they encourage user-generated content in their campaign?"
#         ]
#     },
#     {
#         "question": "CASE STUDY: ‘ChargeOn’ is launching a smart, portable power bank with wireless charging and solar capabilities. The product is more expensive than traditional chargers. ChargeOn wants to target travelers and remote workers.",
#         "options": [
#             "What positioning strategy fits ChargeOn’s value proposition?",
#             "What distribution channel could help them reach their target users?",
#             "What premium pricing tactic can ChargeOn use?",
#             "Which partnership could expand ChargeOn’s brand visibility?"
#         ]
#     },
#     {
#         "question": "CASE STUDY: ‘FreshFleet’ is a new meal delivery service for corporate offices. They provide pre-packaged meals from local chefs. Their mission is to support small culinary businesses while promoting healthy eating.",
#         "options": [
#             "What key benefit should FreshFleet highlight in B2B sales pitches?",
#             "How should they structure their marketing message for HR managers?",
#             "What sales channel would be effective for reaching corporate clients?",
#             "Suggest one loyalty program feature for corporate customers."
#         ]
#     },
#     {
#         "question": "CASE STUDY: ‘MusePrint’ is an on-demand printing platform for artists to sell custom merchandise (posters, shirts, stickers). The platform handles printing, shipping, and customer service.",
#         "options": [
#             "What value proposition can MusePrint offer to artists?",
#             "Which segment of artists should MusePrint target initially?",
#             "What promotional strategy could attract creators to the platform?",
#             "How can MusePrint use social proof to build trust?"
#         ]
#     }
# ]
# # Insert the case analysis questions into the database
# insert_questions_with_topic(case_type_c_questions, "marketing")
