# %%
import pickle

with open('data/simulation_results_2025_08_03_03_45_40.pkl', 'rb') as f:
    data = pickle.load(f)

# %%
data[list(data.keys())[-1]][-5]
# Out:
# {'DAY_KEY': 196,
#  'CUSTOMER_ORDERS_KEY': [{'customer_id': 0,
#    'max_lead_time': 2,
#    'order_cost': 16,
#    'orders': [{'order_id': '0_4_2',
#      'products': [({'product_id': 'B',
#         'processing_time_distributions': {1: 0, 2: 0, 3: 0},
#         'volume_per_unit': 1.5,
#         'cost': 19,
#         'processing_time': 0},
#        3)],
#      'due_time': 2,
#      'status': 'INGREDIENTS_ORDERED'},
#     {'order_id': '0_5_3',
#      'products': [({'product_id': 'B',
#         'processing_time_distributions': {1: 0, 2: 0, 3: 0},
#         'volume_per_unit': 1.5,
#         'cost': 19,
#         'processing_time': 0},
#        5)],
#      'due_time': 2,
#      'status': 'WAITING'},
#     {'order_id': '0_6_4',
#      'products': [({'product_id': 'A',
#         'processing_time_distributions': {1: 0, 2: 0, 3: 0},
#         'volume_per_unit': 1.0,
#         'cost': 15,
#         'processing_time': 0},
#        10)],
#      'due_time': 2,
#      'status': 'WAITING'},
# ...
